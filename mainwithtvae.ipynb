# %%
############################# IMPORT LIBRARY  #################################
import os
import random
import re
from tqdm.notebook import tqdm
from collections import Counter
from datetime import datetime
import argparse
import pickle
import logging
import numpy as np
import pandas as pd

# https://contrib.scikit-learn.org/category_encoders/index.html
import category_encoders as ce
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, QuantileTransformer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

from sklearn.feature_selection import RFE, SelectFromModel, SelectKBest, f_classif, chi2
from sklearn.model_selection import StratifiedKFold, RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier, BaggingClassifier, AdaBoostClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score, roc_auc_score, precision_score, recall_score
from gensim.models import Word2Vec

import optuna
from optuna.samplers import TPESampler, NSGAIISampler, NSGAIIISampler
import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_columns = 200

# %%
#######################   CONFIG  #######################
parser = argparse.ArgumentParser(description='Anomaly Detection')

parser.add_argument('--data_path', type=str, default='./Data')
parser.add_argument('--seed',type=int, default=881)

parser.add_argument('--model', type=str, default='cat')

parser.add_argument('-en', '--encoder', type=str, default='js')
parser.add_argument('-s', '--scaler', type=str, default='qt')

downsample_options = {1:"nearmiss", 2:"cluster", 3:"allknn", 4:"oneside", 5:"tomek"}
parser.add_argument('-ds', '--downsampling', type=int, default=4) # TOMEK

upsample_options = {1: "random", 2:"smote", 3:"adasyn", 4:"smotenc", 5:"smoten", 6:"borderline", 7:"kmeans", 8:"svm", 9: "ctgan", 10: "tvae"}
parser.add_argument('-us', '--upsampling', type=int, default=2) # SVMSMOTE

####### 추가 augmentation으로 CTGAN을 사용하는 경우 #############
augmentation_options = {1: "ctgan", 2: "tvae"}
parser.add_argument('-ag', '--augmentation', type=int, default=2)

parser.add_argument('--fs_mode', type=bool, default=True, help='feature selection T:auto F:manual')
parser.add_argument('--estimator', type=str, default='cat', help="using for feature selection")
parser.add_argument('--selector', type=str, default='kbest', help='auto feature selector')

parser.add_argument('--k', type=int, default=10, help='k fold split')
parser.add_argument('--check_all', type=bool, default=True)
parser.add_argument('--tune_mode', type=bool, default=True, help='optuna tuning')

config = parser.parse_args([])

exp_config = f"{config.encoder}_{config.scaler}_{downsample_options[config.downsampling]}_{upsample_options[config.upsampling]}"

random.seed(config.seed)
np.random.seed(config.seed)

# %%
config
# Out:
# Namespace(data_path='./Data', seed=881, model='cat', encoder='js', scaler='qt', downsampling=4, upsampling=2, augmentation=2, fs_mode=True, estimator='cat', selector='kbest', k=10, check_all=True, tune_mode=True)

# %%
#######################   LOAD DATA  #######################
df_tr = pd.read_csv(os.path.join(config.data_path, "train_v1.csv"))
df_te = pd.read_csv(os.path.join(config.data_path, "test_v1.csv"))
df_list = [df_tr, df_te]

# Workorder (test에 있는데, train에는 없는 경우가 있어 그냥 제외)
# 대신 Workorder Categeory 사용
for df in df_list:
    df.drop(["Workorder"], axis=1, inplace=True)

# %%
############################  FEATURE HANDLING  ###########################
## CATEGORICAL FEATURES
cat_features = ["Equipment_Dam",
                "Equipment_Fill1",
                "Equipment_Fill2",
                "Model.Suffix",
                "Workorder Category",
                "Chamber Temp. Judge Value_AutoClave"]

## BINNING FEATURES
bins_features = df_tr.columns[df_tr.columns.str.contains(r".*Bins.*")].tolist()
# Bins 열 만드는 데 사용된 열
from_bins_features = [re.sub(r'\s*Bins\s*', '', f).strip() for f in bins_features]

cat_features.extend(bins_features)

for df in df_list:
    df[cat_features] = df[cat_features].astype("category")

## NUMERICAL FEATURES
num_features = df_tr.select_dtypes(exclude=["category"]).columns.to_list()
num_features.remove("target")

## ALL FEATURES
all_features = num_features + cat_features

## TARGET ENCODING
df_tr["target"] = df_tr["target"].map({"Normal": 0, "AbNormal": 1})

## DATA SPLITTING 
X_tr, y_tr = df_tr.drop("target", axis=1), df_tr["target"]
X_te = df_te.drop("Set ID", axis=1)

# %%
#############################  FEATURE ENCODING/SCALING ###########################
## ENCODING
if config.encoder == "le":
    le = LabelEncoder()
    for cat_feature in cat_features:
        X_tr[cat_feature] = le.fit_transform(X_tr[cat_feature])
        X_te[cat_feature] = le.transform(X_te[cat_feature])
        
elif config.encoder == "js":
    js = ce.JamesSteinEncoder(cols=cat_features)
    
    X_tr = js.fit_transform(X_tr, y_tr)
    X_te = js.transform(X_te)
    
elif config.encoder == "woe":
    woe = ce.WOEEncoder(cols=cat_features)
    
    X_tr = woe.fit_transform(X_tr, y_tr)
    X_te = woe.transform(X_te)
    
elif config.encoder == "ohe":
    ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)
    
    X_tr[cat_features] = ohe.fit_transform(X_tr[cat_features])
    X_te[cat_features] = ohe.transform(X_te[cat_features])

# %%
## SCALING
if config.scaler == "mms":
    mms = MinMaxScaler()
    X_tr[num_features] = mms.fit_transform(X_tr[num_features])
    X_te[num_features] = mms.transform(X_te[num_features])
    
elif config.scaler == "ss":
    ss = StandardScaler()
    X_tr[num_features] = ss.fit_transform(X_tr[num_features])
    X_te[num_features] = ss.transform(X_te[num_features])
    
elif config.scaler == "qt":
    qt = QuantileTransformer(random_state=config.seed, output_distribution='normal', n_quantiles=min(100, len(X_tr) // 5)) # n_quantiles = 1000
    
    X_tr[num_features] = qt.fit_transform(X_tr[num_features])
    X_te[num_features] = qt.transform(X_te[num_features])

elif config.scaler == "pt":
    pts = PowerTransformer(method='yeo-johnson')
    
    X_tr[num_features] = pts.fit_transform(X_tr[num_features])
    X_te[num_features] = pts.transform(X_te[num_features])

# %%
from collections import Counter
from sklearn.utils import resample
from imblearn.under_sampling import (NearMiss,
                                     ClusterCentroids,
                                     AllKNN,
                                     OneSidedSelection,
                                     TomekLinks)
from imblearn.over_sampling import (RandomOverSampler,
                                    SMOTE,
                                    ADASYN,
                                    SMOTENC,
                                    SMOTEN,
                                    BorderlineSMOTE,
                                    KMeansSMOTE,
                                    SVMSMOTE)
from imblearn.combine import SMOTEENN

# Import libraries for CTGAN and VAE
from ctgan import CTGAN, TVAE
from sklearn.neural_network import MLPRegressor

def random_downsample(df, random_seed, sample_ratio=1.0):
    df_normal = df[df["target"] == 0] 
    df_abnormal = df[df["target"] == 1]
    
    downsampled = resample(
        df_normal,
        replace=False,
        n_samples=int(len(df_abnormal) * sample_ratio),
        random_state=random_seed
    )
    
    downsampled_df = pd.concat([df_abnormal, downsampled])
    
    return downsampled_df

def downsample(X, y, method, random_seed):
    # NearMiss
    if method == "nearmiss":
        # sampling_strategy="auto"
        nm = NearMiss(sampling_strategy=0.4)
        X_downsampled, y_downsampled = nm.fit_resample(X, y)
    # ClusterCentroids
    elif method == "cluster":
        cc = ClusterCentroids(random_state=random_seed)
        X_downsampled, y_downsampled = cc.fit_resample(X, y)
    # AllKNN
    elif method == "allknn":
        allknn = AllKNN()
        X_downsampled, y_downsampled = allknn.fit_resample(X, y)
    # OneSidedSelection
    elif method == "oneside":
        oss = OneSidedSelection(random_state=random_seed)
        X_downsampled, y_downsampled = oss.fit_resample(X, y)
    # Tomeklinks
    elif method == "tomek":
        tl = TomekLinks()
        X_downsampled, y_downsampled = tl.fit_resample(X, y)
    
    X_downsampled_df= pd.DataFrame(X_downsampled, columns=X.columns)
    y_downsampled_df = pd.Series(y_downsampled, name="target") 
    downsampled_df = pd.concat([X_downsampled_df, y_downsampled_df], axis=1)
    
    print('DOWN SAMPLING')
    print('=============')
    print('Original dataset shape %s' % Counter(y))
    print('Resampled dataset shape %s' % Counter(y_downsampled), end='\n')
    
    return downsampled_df


def upsample(X, y, cat_idx, method, random_seed):
    
    if method == "random":
        ros = RandomOverSampler(random_state=random_seed)
        X_upsampled, y_upsampled = ros.fit_resample(X, y)
        
    # SMOTE
    elif method == "smote":
        smote = SMOTE(random_state=random_seed)
        X_upsampled, y_upsampled = smote.fit_resample(X, y)
        
    # ADASYN
    elif method == "adasyn":
        adasyn = ADASYN(random_state=random_seed)
        X_upsampled, y_upsampled = adasyn.fit_resample(X, y)
        
    # SMOTE-NC
    elif method == "smotenc":
        smotenc = SMOTENC(random_state=random_seed, sampling_strategy="auto", categorical_features=cat_idx)
        X_upsampled, y_upsampled = smotenc.fit_resample(X, y)
        
    elif method == "smoten":
        smoten = SMOTEN(random_state=random_seed, sampling_strategy="auto", k_neighbors=5)
        X_upsampled, y_upsampled = smoten.fit_resample(X, y)
        
    elif method == "borderline":
        borderline_smote = BorderlineSMOTE(random_state=random_seed)
        X_upsampled, y_upsampled = borderline_smote.fit_resample(X, y)
        
    elif method == "kmeans":
        kmeans_smote = KMeansSMOTE(random_state=random_seed, sampling_strategy="auto", k_neighbors=5)
        X_upsampled, y_upsampled = kmeans_smote.fit_resample(X, y)
        
    elif method == "svm":
        svm_smote = SVMSMOTE(random_state=42)
        X_upsampled, y_upsampled = svm_smote.fit_resample(X, y)
    
    elif method == "ctgan":
        X = pd.DataFrame(X)
        # Assuming cat_idx is the list of indices of categorical features
        discrete_columns = X.columns[cat_idx]  # Get the names of categorical columns

        # Fit the CTGAN model on the original data
        ctgan = CTGAN(epochs=100)
        ctgan.fit(X, discrete_columns=discrete_columns)

        # Generate synthetic samples
        synthetic_samples = ctgan.sample(X.shape[0])

        # Combine original and synthetic samples
        X_upsampled = pd.concat([X, synthetic_samples])
        y_upsampled = pd.concat([y, pd.Series([1] * synthetic_samples.shape[0], name="target")])
        
    elif method == "tvae":
            if isinstance(X, np.ndarray):
                X = pd.DataFrame(X)
            discrete_columns = X.columns[cat_idx]
            
            tvae = TVAE(epochs=100)
            tvae.fit(X, discrete_columns=discrete_columns)
            synthetic_samples = tvae.sample(X.shape[0])
            
            X_upsampled = pd.concat([X, synthetic_samples])
            y_upsampled = pd.concat([y, pd.Series([1] * synthetic_samples.shape[0], name="target")])
            

    upsampled_df = pd.concat([X_upsampled, y_upsampled], axis=1)
        
    print('UP SAMPLNG')
    print('==========')
    print('Original dataset shape %s' % Counter(y))
    print('Resampled dataset shape %s' % Counter(y_upsampled), end='\n')
    
    return upsampled_df

# %%
#################################  DOWN SAMPLING  ###############################
downsampled_df_tr = downsample(X_tr, y_tr, method=downsample_options[config.downsampling], random_seed=config.seed)

#################################  UP SAMPLING  ###############################
cat_idx = [downsampled_df_tr.columns.get_loc(col) for col in cat_features]
cat_idx = [X_tr.columns.get_loc(col) for col in cat_features]
X_tr = downsampled_df_tr.drop("target", axis=1)
y_tr = downsampled_df_tr["target"]

upsampled_df_tr = upsample(X_tr, y_tr, cat_idx=cat_idx, method=upsample_options[config.upsampling], random_seed=config.seed)
# Out:
# DOWN SAMPLING
# =============
# Original dataset shape Counter({0: 36197, 1: 2210})
# Resampled dataset shape Counter({0: 35239, 1: 2210})
# UP SAMPLNG
# ==========
# Original dataset shape Counter({0: 35239, 1: 2210})
# Resampled dataset shape Counter({0: 35239, 1: 35239})

# %%
## RESAMPLED DATA
# X_tr = downsampled_df_tr.drop("target", axis=1)
# y_tr = downsampled_df_tr["target"]

X_tr = upsampled_df_tr.drop("target", axis=1)
y_tr = upsampled_df_tr["target"]

# %%
X_tr.to_csv(os.path.join(config.data_path, f"train_smote.csv"), index=False)
y_tr.to_csv(os.path.join(config.data_path, f"test_smote.csv"), index=False)

# %%
def augmentation(X, y, method, random_seed):
    print('AUGMENTATION')
    print('==========')
    print('Original dataset shape %s' % Counter(y))
    
    if method == "ctgan":
        X = pd.DataFrame(X)
        # Assuming cat_idx is the list of indices of categorical features
        discrete_columns = X.columns[cat_idx]  # Get the names of categorical columns

        # Fit the CTGAN model on the original data
        ctgan = CTGAN(epochs=100)
        ctgan.fit(X, discrete_columns=discrete_columns)

        # Generate synthetic samples
        synthetic_samples = ctgan.sample(X.shape[0])

        # Combine original and synthetic samples
        X_upsampled = pd.concat([X, synthetic_samples])
        y_upsampled = pd.concat([y, pd.Series([1] * synthetic_samples.shape[0], name="target")])
        
    elif method == "tvae":
        if isinstance(X, np.ndarray):
            X = pd.DataFrame(X)
        discrete_columns = X.columns[cat_idx]
        
        tvae = TVAE(epochs=100)
        tvae.fit(X, discrete_columns=discrete_columns)
        synthetic_samples = tvae.sample(X.shape[0])
        
        X_upsampled = pd.concat([X, synthetic_samples])
        y_upsampled = pd.concat([y, pd.Series([1] * synthetic_samples.shape[0], name="target")])
        
    upsampled_df = pd.concat([X_upsampled, y_upsampled], axis=1)
        
    
    print('Resampled dataset shape %s' % Counter(y_upsampled), end='\n')
    
            
    return augment_df

# %%
augmentation_df = augmentation(X_tr, y_tr, method=augmentation_options[config.augmentation], random_seed=config.seed)

# %%
X_tr = augmentation_df.drop("target", axis=1)
y_tr = augmentation_df["target"]

# %%
################ MODEL ############### 
classifiers = {
    "cat": CatBoostClassifier(random_state=config.seed, auto_class_weights="SqrtBalanced"),
    "lgbm": LGBMClassifier(random_state=config.seed,),
    "xgb": XGBClassifier(random_state=config.seed, eval_metric='auc', objective="binary:logistic"),
    "ada": AdaBoostClassifier(random_state=config.seed),
    "rfc": RandomForestClassifier(random_state=config.seed, class_weight='balanced'),
    "lr": LogisticRegression(random_state=config.seed),
    "extra": ExtraTreesClassifier(random_state=config.seed)
}

# %%
###############################  FEATURE SELECTION  ############################
if config.fs_mode:
    estimator = classifiers[config.estimator]
    estimator.fit(X_tr, y_tr)
    
    selectors = {
        'rfe': RFE(estimator=estimator, n_features_to_select=50),
        'sfm': SelectFromModel(estimator=estimator, threshold="mean"),
        'kbest': SelectKBest(score_func=f_classif, k=10),
    }
    
    selector = selectors[config.selector]
    
    # Fit the selector on the training data
    selector.fit(X_tr, y_tr)
    
    # Get the support mask of selected features
    support_mask = selector.get_support()
    
    # Retain selected features from the original DataFrame and preserve feature names
    X_tr_selec = X_tr.loc[:, support_mask]
    X_te_selec = X_te.loc[:, support_mask]
    
else:
    # 기존 열 대신 Bins 열 사용
    selected_features = [feature for feature in all_features if feature not in from_bins_features]
    
    X_tr_selec = X_tr[selected_features]
    X_te_selec = X_te[selected_features]
    
print("FEATRUE SELECTION")
print("Before ", X_tr.shape)
print("After ", X_tr_selec.shape, end='\n')
# Out:
# Learning rate set to 0.065063
# 0:	learn: 0.5559421	total: 75.5ms	remaining: 1m 15s
# 1:	learn: 0.4482026	total: 113ms	remaining: 56.6s
# 2:	learn: 0.3740895	total: 142ms	remaining: 47s
# 3:	learn: 0.3181010	total: 172ms	remaining: 42.8s
# 4:	learn: 0.2716881	total: 196ms	remaining: 39.1s
# 5:	learn: 0.2361149	total: 219ms	remaining: 36.2s
# 6:	learn: 0.2136012	total: 241ms	remaining: 34.2s
# 7:	learn: 0.1925237	total: 260ms	remaining: 32.2s
# 8:	learn: 0.1768716	total: 281ms	remaining: 31s
# 9:	learn: 0.1642499	total: 303ms	remaining: 30s
# 10:	learn: 0.1545142	total: 321ms	remaining: 28.9s
# 11:	learn: 0.1473661	total: 339ms	remaining: 27.9s
# 12:	learn: 0.1408403	total: 356ms	remaining: 27s
# 13:	learn: 0.1355074	total: 372ms	remaining: 26.2s
# 14:	learn: 0.1312999	total: 390ms	remaining: 25.6s
# 15:	learn: 0.1277541	total: 410ms	remaining: 25.2s
# 16:	learn: 0.1248652	total: 432ms	remaining: 25s
# 17:	learn: 0.1222227	total: 451ms	remaining: 24.6s
# 18:	learn: 0.1201507	total: 469ms	remaining: 24.2s
# 19:	learn: 0.1184458	total: 490ms	remaining: 24s
# 20:	learn: 0.1167536	total: 511ms	remaining: 23.8s
# 21:	learn: 0.1153412	total: 535ms	remaining: 23.8s
# 22:	learn: 0.1141406	total: 556ms	remaining: 23.6s
# 23:	learn: 0.1130420	total: 578ms	remaining: 23.5s
# 24:	learn: 0.1122812	total: 599ms	remaining: 23.3s
# 25:	learn: 0.1115964	total: 619ms	remaining: 23.2s
# 26:	learn: 0.1110027	total: 649ms	remaining: 23.4s
# 27:	learn: 0.1104837	total: 672ms	remaining: 23.3s
# 28:	learn: 0.1099019	total: 694ms	remaining: 23.3s
# 29:	learn: 0.1092114	total: 716ms	remaining: 23.2s
# 30:	learn: 0.1087601	total: 735ms	remaining: 23s
# 31:	learn: 0.1083820	total: 758ms	remaining: 22.9s
# 32:	learn: 0.1078859	total: 778ms	remaining: 22.8s
# 33:	learn: 0.1075922	total: 797ms	remaining: 22.6s
# 34:	learn: 0.1073344	total: 818ms	remaining: 22.6s
# 35:	learn: 0.1070525	total: 841ms	remaining: 22.5s
# 36:	learn: 0.1068692	total: 867ms	remaining: 22.6s
# 37:	learn: 0.1066779	total: 895ms	remaining: 22.6s
# 38:	learn: 0.1064947	total: 926ms	remaining: 22.8s
# 39:	learn: 0.1063376	total: 947ms	remaining: 22.7s
# 40:	learn: 0.1062041	total: 968ms	remaining: 22.6s
# 41:	learn: 0.1060137	total: 992ms	remaining: 22.6s
# 42:	learn: 0.1058353	total: 1.02s	remaining: 22.7s
# 43:	learn: 0.1057172	total: 1.04s	remaining: 22.6s
# 44:	learn: 0.1055902	total: 1.06s	remaining: 22.5s
# 45:	learn: 0.1054669	total: 1.08s	remaining: 22.4s
# 46:	learn: 0.1053386	total: 1.1s	remaining: 22.4s
# 47:	learn: 0.1052335	total: 1.12s	remaining: 22.3s
# 48:	learn: 0.1051657	total: 1.14s	remaining: 22.1s
# 49:	learn: 0.1050821	total: 1.16s	remaining: 22.1s
# 50:	learn: 0.1049575	total: 1.18s	remaining: 22s
# 51:	learn: 0.1048555	total: 1.2s	remaining: 21.9s
# 52:	learn: 0.1047325	total: 1.22s	remaining: 21.8s
# 53:	learn: 0.1046223	total: 1.25s	remaining: 21.8s
# 54:	learn: 0.1045506	total: 1.26s	remaining: 21.7s
# 55:	learn: 0.1044946	total: 1.28s	remaining: 21.7s
# 56:	learn: 0.1044319	total: 1.3s	remaining: 21.6s
# 57:	learn: 0.1043537	total: 1.32s	remaining: 21.5s
# 58:	learn: 0.1042746	total: 1.34s	remaining: 21.4s
# 59:	learn: 0.1042150	total: 1.36s	remaining: 21.4s
# 60:	learn: 0.1041501	total: 1.39s	remaining: 21.3s
# 61:	learn: 0.1040911	total: 1.4s	remaining: 21.2s
# 62:	learn: 0.1040336	total: 1.42s	remaining: 21.2s
# 63:	learn: 0.1039766	total: 1.44s	remaining: 21.1s
# 64:	learn: 0.1039358	total: 1.46s	remaining: 21s
# 65:	learn: 0.1038678	total: 1.49s	remaining: 21.1s
# 66:	learn: 0.1038010	total: 1.51s	remaining: 21.1s
# 67:	learn: 0.1037577	total: 1.53s	remaining: 21.1s
# 68:	learn: 0.1036826	total: 1.56s	remaining: 21s
# 69:	learn: 0.1035954	total: 1.58s	remaining: 21s
# 70:	learn: 0.1034885	total: 1.6s	remaining: 20.9s
# 71:	learn: 0.1034203	total: 1.61s	remaining: 20.8s
# 72:	learn: 0.1033930	total: 1.63s	remaining: 20.7s
# 73:	learn: 0.1033721	total: 1.65s	remaining: 20.7s
# 74:	learn: 0.1033108	total: 1.67s	remaining: 20.6s
# 75:	learn: 0.1032333	total: 1.69s	remaining: 20.6s
# 76:	learn: 0.1031968	total: 1.71s	remaining: 20.5s
# 77:	learn: 0.1031410	total: 1.73s	remaining: 20.4s
# 78:	learn: 0.1031038	total: 1.74s	remaining: 20.3s
# 79:	learn: 0.1030434	total: 1.76s	remaining: 20.3s
# 80:	learn: 0.1029113	total: 1.78s	remaining: 20.2s
# 81:	learn: 0.1028738	total: 1.8s	remaining: 20.2s
# 82:	learn: 0.1028321	total: 1.82s	remaining: 20.1s
# 83:	learn: 0.1027917	total: 1.84s	remaining: 20.1s
# 84:	learn: 0.1026957	total: 1.86s	remaining: 20.1s
# 85:	learn: 0.1026497	total: 1.88s	remaining: 20s
# 86:	learn: 0.1025864	total: 1.91s	remaining: 20s
# 87:	learn: 0.1025318	total: 1.93s	remaining: 20s
# 88:	learn: 0.1024737	total: 1.95s	remaining: 20s
# 89:	learn: 0.1024165	total: 1.97s	remaining: 19.9s
# 90:	learn: 0.1023910	total: 1.99s	remaining: 19.8s
# 91:	learn: 0.1023756	total: 2.01s	remaining: 19.8s
# 92:	learn: 0.1023403	total: 2.03s	remaining: 19.8s
# 93:	learn: 0.1022721	total: 2.06s	remaining: 19.8s
# 94:	learn: 0.1021679	total: 2.08s	remaining: 19.8s
# 95:	learn: 0.1020752	total: 2.09s	remaining: 19.7s
# 96:	learn: 0.1020074	total: 2.11s	remaining: 19.7s
# 97:	learn: 0.1019582	total: 2.13s	remaining: 19.6s
# 98:	learn: 0.1019096	total: 2.16s	remaining: 19.6s
# 99:	learn: 0.1018527	total: 2.18s	remaining: 19.6s
# 100:	learn: 0.1018061	total: 2.21s	remaining: 19.7s
# 101:	learn: 0.1017467	total: 2.23s	remaining: 19.7s
# 102:	learn: 0.1016803	total: 2.26s	remaining: 19.7s
# 103:	learn: 0.1016212	total: 2.29s	remaining: 19.7s
# 104:	learn: 0.1015828	total: 2.31s	remaining: 19.7s
# 105:	learn: 0.1015284	total: 2.34s	remaining: 19.7s
# 106:	learn: 0.1015065	total: 2.36s	remaining: 19.7s
# 107:	learn: 0.1014493	total: 2.38s	remaining: 19.7s
# 108:	learn: 0.1014241	total: 2.4s	remaining: 19.6s
# 109:	learn: 0.1014012	total: 2.42s	remaining: 19.6s
# 110:	learn: 0.1013580	total: 2.44s	remaining: 19.6s
# 111:	learn: 0.1013233	total: 2.46s	remaining: 19.5s
# 112:	learn: 0.1012983	total: 2.49s	remaining: 19.5s
# 113:	learn: 0.1012477	total: 2.51s	remaining: 19.5s
# 114:	learn: 0.1011826	total: 2.53s	remaining: 19.5s
# 115:	learn: 0.1011323	total: 2.55s	remaining: 19.4s
# 116:	learn: 0.1011025	total: 2.57s	remaining: 19.4s
# 117:	learn: 0.1010742	total: 2.61s	remaining: 19.5s
# 118:	learn: 0.1010312	total: 2.63s	remaining: 19.5s
# 119:	learn: 0.1009899	total: 2.66s	remaining: 19.5s
# 120:	learn: 0.1009538	total: 2.68s	remaining: 19.4s
# 121:	learn: 0.1009175	total: 2.7s	remaining: 19.5s
# 122:	learn: 0.1008678	total: 2.72s	remaining: 19.4s
# 123:	learn: 0.1008217	total: 2.74s	remaining: 19.4s
# 124:	learn: 0.1007879	total: 2.76s	remaining: 19.3s
# 125:	learn: 0.1007544	total: 2.78s	remaining: 19.3s
# 126:	learn: 0.1007182	total: 2.8s	remaining: 19.2s
# 127:	learn: 0.1006856	total: 2.82s	remaining: 19.2s
# 128:	learn: 0.1006540	total: 2.84s	remaining: 19.2s
# 129:	learn: 0.1006275	total: 2.86s	remaining: 19.1s
# 130:	learn: 0.1005781	total: 2.88s	remaining: 19.1s
# 131:	learn: 0.1005393	total: 2.9s	remaining: 19.1s
# 132:	learn: 0.1004880	total: 2.92s	remaining: 19s
# 133:	learn: 0.1004567	total: 2.94s	remaining: 19s
# 134:	learn: 0.1004390	total: 2.97s	remaining: 19s
# 135:	learn: 0.1004118	total: 2.98s	remaining: 19s
# 136:	learn: 0.1003929	total: 3s	remaining: 18.9s
# 137:	learn: 0.1003719	total: 3.02s	remaining: 18.9s
# 138:	learn: 0.1003461	total: 3.04s	remaining: 18.8s
# 139:	learn: 0.1003037	total: 3.06s	remaining: 18.8s
# 140:	learn: 0.1002446	total: 3.08s	remaining: 18.8s
# 141:	learn: 0.1001905	total: 3.11s	remaining: 18.8s
# 142:	learn: 0.1001452	total: 3.13s	remaining: 18.8s
# 143:	learn: 0.1001190	total: 3.15s	remaining: 18.7s
# 144:	learn: 0.1000638	total: 3.17s	remaining: 18.7s
# 145:	learn: 0.1000268	total: 3.2s	remaining: 18.7s
# 146:	learn: 0.0999723	total: 3.22s	remaining: 18.7s
# 147:	learn: 0.0999307	total: 3.24s	remaining: 18.6s
# 148:	learn: 0.0998816	total: 3.26s	remaining: 18.6s
# 149:	learn: 0.0998356	total: 3.28s	remaining: 18.6s
# 150:	learn: 0.0998016	total: 3.29s	remaining: 18.5s
# 151:	learn: 0.0997732	total: 3.32s	remaining: 18.5s
# 152:	learn: 0.0997507	total: 3.33s	remaining: 18.5s
# 153:	learn: 0.0997188	total: 3.35s	remaining: 18.4s
# 154:	learn: 0.0996639	total: 3.37s	remaining: 18.4s
# 155:	learn: 0.0996391	total: 3.39s	remaining: 18.3s
# 156:	learn: 0.0995900	total: 3.41s	remaining: 18.3s
# 157:	learn: 0.0995643	total: 3.42s	remaining: 18.3s
# 158:	learn: 0.0995064	total: 3.45s	remaining: 18.2s
# 159:	learn: 0.0994711	total: 3.46s	remaining: 18.2s
# 160:	learn: 0.0994508	total: 3.48s	remaining: 18.1s
# 161:	learn: 0.0993935	total: 3.5s	remaining: 18.1s
# 162:	learn: 0.0993706	total: 3.52s	remaining: 18.1s
# 163:	learn: 0.0993496	total: 3.54s	remaining: 18s
# 164:	learn: 0.0992819	total: 3.56s	remaining: 18s
# 165:	learn: 0.0992220	total: 3.58s	remaining: 18s
# 166:	learn: 0.0991985	total: 3.59s	remaining: 17.9s
# 167:	learn: 0.0991804	total: 3.61s	remaining: 17.9s
# 168:	learn: 0.0991433	total: 3.63s	remaining: 17.9s
# 169:	learn: 0.0991071	total: 3.65s	remaining: 17.8s
# 170:	learn: 0.0990531	total: 3.67s	remaining: 17.8s
# 171:	learn: 0.0990185	total: 3.68s	remaining: 17.7s
# 172:	learn: 0.0989767	total: 3.7s	remaining: 17.7s
# 173:	learn: 0.0989548	total: 3.72s	remaining: 17.7s
# 174:	learn: 0.0989159	total: 3.74s	remaining: 17.6s
# 175:	learn: 0.0988613	total: 3.75s	remaining: 17.6s
# 176:	learn: 0.0988415	total: 3.77s	remaining: 17.5s
# 177:	learn: 0.0987995	total: 3.79s	remaining: 17.5s
# 178:	learn: 0.0987657	total: 3.81s	remaining: 17.5s
# 179:	learn: 0.0987351	total: 3.83s	remaining: 17.4s
# 180:	learn: 0.0987013	total: 3.85s	remaining: 17.4s
# 181:	learn: 0.0986705	total: 3.86s	remaining: 17.4s
# 182:	learn: 0.0986282	total: 3.88s	remaining: 17.3s
# 183:	learn: 0.0986040	total: 3.9s	remaining: 17.3s
# 184:	learn: 0.0985783	total: 3.92s	remaining: 17.3s
# 185:	learn: 0.0985636	total: 3.95s	remaining: 17.3s
# 186:	learn: 0.0985169	total: 3.97s	remaining: 17.3s
# 187:	learn: 0.0984777	total: 3.99s	remaining: 17.2s
# 188:	learn: 0.0984276	total: 4.01s	remaining: 17.2s
# 189:	learn: 0.0983873	total: 4.03s	remaining: 17.2s
# 190:	learn: 0.0983604	total: 4.05s	remaining: 17.2s
# 191:	learn: 0.0983373	total: 4.07s	remaining: 17.1s
# 192:	learn: 0.0983067	total: 4.09s	remaining: 17.1s
# 193:	learn: 0.0982817	total: 4.11s	remaining: 17.1s
# 194:	learn: 0.0982357	total: 4.13s	remaining: 17s
# 195:	learn: 0.0981946	total: 4.15s	remaining: 17s
# 196:	learn: 0.0981458	total: 4.17s	remaining: 17s
# 197:	learn: 0.0981193	total: 4.19s	remaining: 17s
# 198:	learn: 0.0980857	total: 4.21s	remaining: 17s
# 199:	learn: 0.0980741	total: 4.23s	remaining: 16.9s
# 200:	learn: 0.0980361	total: 4.25s	remaining: 16.9s
# 201:	learn: 0.0979983	total: 4.27s	remaining: 16.9s
# 202:	learn: 0.0979581	total: 4.29s	remaining: 16.8s
# 203:	learn: 0.0979043	total: 4.31s	remaining: 16.8s
# 204:	learn: 0.0978370	total: 4.33s	remaining: 16.8s
# 205:	learn: 0.0978267	total: 4.34s	remaining: 16.8s
# 206:	learn: 0.0977712	total: 4.36s	remaining: 16.7s
# 207:	learn: 0.0977629	total: 4.38s	remaining: 16.7s
# 208:	learn: 0.0977336	total: 4.4s	remaining: 16.6s
# 209:	learn: 0.0977150	total: 4.42s	remaining: 16.6s
# 210:	learn: 0.0976797	total: 4.43s	remaining: 16.6s
# 211:	learn: 0.0976504	total: 4.45s	remaining: 16.6s
# 212:	learn: 0.0976269	total: 4.47s	remaining: 16.5s
# 213:	learn: 0.0975999	total: 4.49s	remaining: 16.5s
# 214:	learn: 0.0975850	total: 4.51s	remaining: 16.5s
# 215:	learn: 0.0975717	total: 4.54s	remaining: 16.5s
# 216:	learn: 0.0975631	total: 4.56s	remaining: 16.4s
# 217:	learn: 0.0975445	total: 4.58s	remaining: 16.4s
# 218:	learn: 0.0975296	total: 4.59s	remaining: 16.4s
# 219:	learn: 0.0975039	total: 4.61s	remaining: 16.3s
# 220:	learn: 0.0974788	total: 4.63s	remaining: 16.3s
# 221:	learn: 0.0974561	total: 4.65s	remaining: 16.3s
# 222:	learn: 0.0974494	total: 4.66s	remaining: 16.3s
# 223:	learn: 0.0974087	total: 4.68s	remaining: 16.2s
# 224:	learn: 0.0973613	total: 4.7s	remaining: 16.2s
# 225:	learn: 0.0973252	total: 4.73s	remaining: 16.2s
# 226:	learn: 0.0972929	total: 4.75s	remaining: 16.2s
# 227:	learn: 0.0972670	total: 4.77s	remaining: 16.2s
# 228:	learn: 0.0972230	total: 4.79s	remaining: 16.1s
# 229:	learn: 0.0971920	total: 4.8s	remaining: 16.1s
# 230:	learn: 0.0971586	total: 4.82s	remaining: 16.1s
# 231:	learn: 0.0971077	total: 4.84s	remaining: 16s
# 232:	learn: 0.0970864	total: 4.86s	remaining: 16s
# 233:	learn: 0.0970585	total: 4.88s	remaining: 16s
# 234:	learn: 0.0970419	total: 4.9s	remaining: 15.9s
# 235:	learn: 0.0970032	total: 4.92s	remaining: 15.9s
# 236:	learn: 0.0969551	total: 4.94s	remaining: 15.9s
# 237:	learn: 0.0969196	total: 4.97s	remaining: 15.9s
# 238:	learn: 0.0969078	total: 4.99s	remaining: 15.9s
# 239:	learn: 0.0968690	total: 5.01s	remaining: 15.9s
# 240:	learn: 0.0968354	total: 5.02s	remaining: 15.8s
# 241:	learn: 0.0968049	total: 5.05s	remaining: 15.8s
# 242:	learn: 0.0967732	total: 5.07s	remaining: 15.8s
# 243:	learn: 0.0967477	total: 5.09s	remaining: 15.8s
# 244:	learn: 0.0967073	total: 5.11s	remaining: 15.8s
# 245:	learn: 0.0966742	total: 5.13s	remaining: 15.7s
# 246:	learn: 0.0966365	total: 5.15s	remaining: 15.7s
# 247:	learn: 0.0965998	total: 5.17s	remaining: 15.7s
# 248:	learn: 0.0965648	total: 5.2s	remaining: 15.7s
# 249:	learn: 0.0965315	total: 5.21s	remaining: 15.6s
# 250:	learn: 0.0964824	total: 5.23s	remaining: 15.6s
# 251:	learn: 0.0964672	total: 5.25s	remaining: 15.6s
# 252:	learn: 0.0964409	total: 5.28s	remaining: 15.6s
# 253:	learn: 0.0964085	total: 5.3s	remaining: 15.6s
# 254:	learn: 0.0963962	total: 5.32s	remaining: 15.5s
# 255:	learn: 0.0963445	total: 5.34s	remaining: 15.5s
# 256:	learn: 0.0963064	total: 5.36s	remaining: 15.5s
# 257:	learn: 0.0962845	total: 5.37s	remaining: 15.5s
# 258:	learn: 0.0962585	total: 5.39s	remaining: 15.4s
# 259:	learn: 0.0962376	total: 5.41s	remaining: 15.4s
# 260:	learn: 0.0961896	total: 5.43s	remaining: 15.4s
# 261:	learn: 0.0961744	total: 5.44s	remaining: 15.3s
# 262:	learn: 0.0961592	total: 5.46s	remaining: 15.3s
# 263:	learn: 0.0961331	total: 5.48s	remaining: 15.3s
# 264:	learn: 0.0961047	total: 5.5s	remaining: 15.2s
# 265:	learn: 0.0960700	total: 5.51s	remaining: 15.2s
# 266:	learn: 0.0960501	total: 5.54s	remaining: 15.2s
# 267:	learn: 0.0960147	total: 5.55s	remaining: 15.2s
# 268:	learn: 0.0959931	total: 5.57s	remaining: 15.1s
# 269:	learn: 0.0959650	total: 5.59s	remaining: 15.1s
# 270:	learn: 0.0959288	total: 5.61s	remaining: 15.1s
# 271:	learn: 0.0959220	total: 5.62s	remaining: 15.1s
# 272:	learn: 0.0958547	total: 5.65s	remaining: 15s
# 273:	learn: 0.0958033	total: 5.67s	remaining: 15s
# 274:	learn: 0.0957610	total: 5.7s	remaining: 15s
# 275:	learn: 0.0957407	total: 5.72s	remaining: 15s
# 276:	learn: 0.0957302	total: 5.74s	remaining: 15s
# 277:	learn: 0.0957122	total: 5.76s	remaining: 15s
# 278:	learn: 0.0956876	total: 5.79s	remaining: 15s
# 279:	learn: 0.0956580	total: 5.81s	remaining: 14.9s
# 280:	learn: 0.0956274	total: 5.84s	remaining: 15s
# 281:	learn: 0.0956053	total: 5.86s	remaining: 14.9s
# 282:	learn: 0.0955708	total: 5.89s	remaining: 14.9s
# 283:	learn: 0.0955559	total: 5.9s	remaining: 14.9s
# 284:	learn: 0.0955258	total: 5.92s	remaining: 14.9s
# 285:	learn: 0.0954789	total: 5.95s	remaining: 14.8s
# 286:	learn: 0.0954370	total: 5.97s	remaining: 14.8s
# 287:	learn: 0.0953857	total: 5.99s	remaining: 14.8s
# 288:	learn: 0.0953762	total: 6.01s	remaining: 14.8s
# 289:	learn: 0.0953631	total: 6.03s	remaining: 14.8s
# 290:	learn: 0.0953391	total: 6.05s	remaining: 14.7s
# 291:	learn: 0.0952974	total: 6.07s	remaining: 14.7s
# 292:	learn: 0.0952763	total: 6.09s	remaining: 14.7s
# 293:	learn: 0.0952464	total: 6.1s	remaining: 14.7s
# 294:	learn: 0.0952354	total: 6.12s	remaining: 14.6s
# 295:	learn: 0.0952033	total: 6.14s	remaining: 14.6s
# 296:	learn: 0.0951806	total: 6.16s	remaining: 14.6s
# 297:	learn: 0.0951400	total: 6.18s	remaining: 14.6s
# 298:	learn: 0.0950816	total: 6.2s	remaining: 14.5s
# 299:	learn: 0.0950424	total: 6.22s	remaining: 14.5s
# 300:	learn: 0.0950192	total: 6.24s	remaining: 14.5s
# 301:	learn: 0.0949897	total: 6.25s	remaining: 14.5s
# 302:	learn: 0.0949531	total: 6.28s	remaining: 14.4s
# 303:	learn: 0.0948760	total: 6.3s	remaining: 14.4s
# 304:	learn: 0.0948542	total: 6.32s	remaining: 14.4s
# 305:	learn: 0.0948385	total: 6.33s	remaining: 14.4s
# 306:	learn: 0.0947949	total: 6.35s	remaining: 14.3s
# 307:	learn: 0.0947683	total: 6.37s	remaining: 14.3s
# 308:	learn: 0.0947160	total: 6.39s	remaining: 14.3s
# 309:	learn: 0.0947003	total: 6.41s	remaining: 14.3s
# 310:	learn: 0.0946545	total: 6.43s	remaining: 14.2s
# 311:	learn: 0.0946205	total: 6.45s	remaining: 14.2s
# 312:	learn: 0.0945965	total: 6.47s	remaining: 14.2s
# 313:	learn: 0.0945709	total: 6.49s	remaining: 14.2s
# 314:	learn: 0.0945401	total: 6.52s	remaining: 14.2s
# 315:	learn: 0.0945211	total: 6.53s	remaining: 14.1s
# 316:	learn: 0.0944941	total: 6.56s	remaining: 14.1s
# 317:	learn: 0.0944418	total: 6.57s	remaining: 14.1s
# 318:	learn: 0.0944037	total: 6.59s	remaining: 14.1s
# 319:	learn: 0.0943868	total: 6.62s	remaining: 14.1s
# 320:	learn: 0.0943634	total: 6.64s	remaining: 14s
# 321:	learn: 0.0943301	total: 6.67s	remaining: 14s
# 322:	learn: 0.0943120	total: 6.68s	remaining: 14s
# 323:	learn: 0.0942848	total: 6.7s	remaining: 14s
# 324:	learn: 0.0942465	total: 6.72s	remaining: 14s
# 325:	learn: 0.0941887	total: 6.75s	remaining: 14s
# 326:	learn: 0.0941427	total: 6.77s	remaining: 13.9s
# 327:	learn: 0.0941227	total: 6.79s	remaining: 13.9s
# 328:	learn: 0.0941047	total: 6.82s	remaining: 13.9s
# 329:	learn: 0.0940707	total: 6.83s	remaining: 13.9s
# 330:	learn: 0.0940334	total: 6.86s	remaining: 13.9s
# 331:	learn: 0.0940051	total: 6.87s	remaining: 13.8s
# 332:	learn: 0.0939645	total: 6.9s	remaining: 13.8s
# 333:	learn: 0.0939441	total: 6.91s	remaining: 13.8s
# 334:	learn: 0.0939207	total: 6.93s	remaining: 13.8s
# 335:	learn: 0.0939088	total: 6.95s	remaining: 13.7s
# 336:	learn: 0.0938782	total: 6.97s	remaining: 13.7s
# 337:	learn: 0.0938391	total: 6.99s	remaining: 13.7s
# 338:	learn: 0.0938233	total: 7.01s	remaining: 13.7s
# 339:	learn: 0.0938173	total: 7.02s	remaining: 13.6s
# 340:	learn: 0.0938009	total: 7.04s	remaining: 13.6s
# 341:	learn: 0.0937785	total: 7.06s	remaining: 13.6s
# 342:	learn: 0.0937404	total: 7.08s	remaining: 13.6s
# 343:	learn: 0.0937046	total: 7.09s	remaining: 13.5s
# 344:	learn: 0.0936525	total: 7.11s	remaining: 13.5s
# 345:	learn: 0.0936223	total: 7.13s	remaining: 13.5s
# 346:	learn: 0.0935987	total: 7.15s	remaining: 13.5s
# 347:	learn: 0.0935636	total: 7.17s	remaining: 13.4s
# 348:	learn: 0.0935380	total: 7.19s	remaining: 13.4s
# 349:	learn: 0.0935058	total: 7.21s	remaining: 13.4s
# 350:	learn: 0.0934804	total: 7.22s	remaining: 13.4s
# 351:	learn: 0.0934558	total: 7.24s	remaining: 13.3s
# 352:	learn: 0.0934244	total: 7.26s	remaining: 13.3s
# 353:	learn: 0.0934018	total: 7.28s	remaining: 13.3s
# 354:	learn: 0.0933730	total: 7.3s	remaining: 13.3s
# 355:	learn: 0.0933262	total: 7.32s	remaining: 13.2s
# 356:	learn: 0.0932940	total: 7.34s	remaining: 13.2s
# 357:	learn: 0.0932850	total: 7.36s	remaining: 13.2s
# 358:	learn: 0.0932545	total: 7.38s	remaining: 13.2s
# 359:	learn: 0.0931921	total: 7.4s	remaining: 13.2s
# 360:	learn: 0.0931639	total: 7.42s	remaining: 13.1s
# 361:	learn: 0.0931325	total: 7.44s	remaining: 13.1s
# 362:	learn: 0.0931060	total: 7.46s	remaining: 13.1s
# 363:	learn: 0.0930871	total: 7.47s	remaining: 13.1s
# 364:	learn: 0.0930651	total: 7.49s	remaining: 13s
# 365:	learn: 0.0930268	total: 7.51s	remaining: 13s
# 366:	learn: 0.0930042	total: 7.53s	remaining: 13s
# 367:	learn: 0.0929717	total: 7.55s	remaining: 13s
# 368:	learn: 0.0929455	total: 7.57s	remaining: 12.9s
# 369:	learn: 0.0928815	total: 7.59s	remaining: 12.9s
# 370:	learn: 0.0928496	total: 7.61s	remaining: 12.9s
# 371:	learn: 0.0928231	total: 7.63s	remaining: 12.9s
# 372:	learn: 0.0928022	total: 7.65s	remaining: 12.9s
# 373:	learn: 0.0927688	total: 7.67s	remaining: 12.8s
# 374:	learn: 0.0927114	total: 7.7s	remaining: 12.8s
# 375:	learn: 0.0926935	total: 7.71s	remaining: 12.8s
# 376:	learn: 0.0926500	total: 7.73s	remaining: 12.8s
# 377:	learn: 0.0926232	total: 7.75s	remaining: 12.8s
# 378:	learn: 0.0925767	total: 7.78s	remaining: 12.7s
# 379:	learn: 0.0925329	total: 7.8s	remaining: 12.7s
# 380:	learn: 0.0924988	total: 7.82s	remaining: 12.7s
# 381:	learn: 0.0924641	total: 7.86s	remaining: 12.7s
# 382:	learn: 0.0924077	total: 7.88s	remaining: 12.7s
# 383:	learn: 0.0923814	total: 7.9s	remaining: 12.7s
# 384:	learn: 0.0923438	total: 7.92s	remaining: 12.7s
# 385:	learn: 0.0923063	total: 7.95s	remaining: 12.6s
# 386:	learn: 0.0922392	total: 7.96s	remaining: 12.6s
# 387:	learn: 0.0921991	total: 7.98s	remaining: 12.6s
# 388:	learn: 0.0921789	total: 8.01s	remaining: 12.6s
# 389:	learn: 0.0921572	total: 8.02s	remaining: 12.6s
# 390:	learn: 0.0921333	total: 8.05s	remaining: 12.5s
# 391:	learn: 0.0921189	total: 8.07s	remaining: 12.5s
# 392:	learn: 0.0920925	total: 8.09s	remaining: 12.5s
# 393:	learn: 0.0920844	total: 8.11s	remaining: 12.5s
# 394:	learn: 0.0920340	total: 8.13s	remaining: 12.4s
# 395:	learn: 0.0919854	total: 8.14s	remaining: 12.4s
# 396:	learn: 0.0919631	total: 8.16s	remaining: 12.4s
# 397:	learn: 0.0919391	total: 8.18s	remaining: 12.4s
# 398:	learn: 0.0918993	total: 8.2s	remaining: 12.3s
# 399:	learn: 0.0918591	total: 8.22s	remaining: 12.3s
# 400:	learn: 0.0917995	total: 8.24s	remaining: 12.3s
# 401:	learn: 0.0917694	total: 8.26s	remaining: 12.3s
# 402:	learn: 0.0917188	total: 8.27s	remaining: 12.3s
# 403:	learn: 0.0916773	total: 8.29s	remaining: 12.2s
# 404:	learn: 0.0916145	total: 8.31s	remaining: 12.2s
# 405:	learn: 0.0915882	total: 8.34s	remaining: 12.2s
# 406:	learn: 0.0915645	total: 8.35s	remaining: 12.2s
# 407:	learn: 0.0915310	total: 8.37s	remaining: 12.1s
# 408:	learn: 0.0915088	total: 8.39s	remaining: 12.1s
# 409:	learn: 0.0914767	total: 8.41s	remaining: 12.1s
# 410:	learn: 0.0914681	total: 8.43s	remaining: 12.1s
# 411:	learn: 0.0914202	total: 8.45s	remaining: 12.1s
# 412:	learn: 0.0913950	total: 8.46s	remaining: 12s
# 413:	learn: 0.0913637	total: 8.49s	remaining: 12s
# 414:	learn: 0.0913187	total: 8.51s	remaining: 12s
# 415:	learn: 0.0912677	total: 8.52s	remaining: 12s
# 416:	learn: 0.0912526	total: 8.54s	remaining: 11.9s
# 417:	learn: 0.0912156	total: 8.56s	remaining: 11.9s
# 418:	learn: 0.0911620	total: 8.58s	remaining: 11.9s
# 419:	learn: 0.0911196	total: 8.6s	remaining: 11.9s
# 420:	learn: 0.0910830	total: 8.62s	remaining: 11.8s
# 421:	learn: 0.0910606	total: 8.63s	remaining: 11.8s
# 422:	learn: 0.0910204	total: 8.65s	remaining: 11.8s
# 423:	learn: 0.0909822	total: 8.67s	remaining: 11.8s
# 424:	learn: 0.0909599	total: 8.69s	remaining: 11.8s
# 425:	learn: 0.0909058	total: 8.71s	remaining: 11.7s
# 426:	learn: 0.0908788	total: 8.73s	remaining: 11.7s
# 427:	learn: 0.0908404	total: 8.75s	remaining: 11.7s
# 428:	learn: 0.0907891	total: 8.77s	remaining: 11.7s
# 429:	learn: 0.0907685	total: 8.79s	remaining: 11.6s
# 430:	learn: 0.0907522	total: 8.81s	remaining: 11.6s
# 431:	learn: 0.0907137	total: 8.84s	remaining: 11.6s
# 432:	learn: 0.0906901	total: 8.87s	remaining: 11.6s
# 433:	learn: 0.0906632	total: 8.88s	remaining: 11.6s
# 434:	learn: 0.0906304	total: 8.92s	remaining: 11.6s
# 435:	learn: 0.0906056	total: 8.93s	remaining: 11.6s
# 436:	learn: 0.0905767	total: 8.95s	remaining: 11.5s
# 437:	learn: 0.0905535	total: 8.97s	remaining: 11.5s
# 438:	learn: 0.0905115	total: 8.99s	remaining: 11.5s
# 439:	learn: 0.0904832	total: 9.01s	remaining: 11.5s
# 440:	learn: 0.0904344	total: 9.04s	remaining: 11.5s
# 441:	learn: 0.0904192	total: 9.06s	remaining: 11.4s
# 442:	learn: 0.0904049	total: 9.1s	remaining: 11.4s
# 443:	learn: 0.0903664	total: 9.12s	remaining: 11.4s
# 444:	learn: 0.0903410	total: 9.14s	remaining: 11.4s
# 445:	learn: 0.0903105	total: 9.16s	remaining: 11.4s
# 446:	learn: 0.0902755	total: 9.18s	remaining: 11.4s
# 447:	learn: 0.0902413	total: 9.2s	remaining: 11.3s
# 448:	learn: 0.0902174	total: 9.22s	remaining: 11.3s
# 449:	learn: 0.0901968	total: 9.23s	remaining: 11.3s
# 450:	learn: 0.0901872	total: 9.26s	remaining: 11.3s
# 451:	learn: 0.0901466	total: 9.28s	remaining: 11.2s
# 452:	learn: 0.0901099	total: 9.29s	remaining: 11.2s
# 453:	learn: 0.0900813	total: 9.32s	remaining: 11.2s
# 454:	learn: 0.0900521	total: 9.34s	remaining: 11.2s
# 455:	learn: 0.0900308	total: 9.36s	remaining: 11.2s
# 456:	learn: 0.0900195	total: 9.37s	remaining: 11.1s
# 457:	learn: 0.0899664	total: 9.39s	remaining: 11.1s
# 458:	learn: 0.0899495	total: 9.41s	remaining: 11.1s
# 459:	learn: 0.0899163	total: 9.43s	remaining: 11.1s
# 460:	learn: 0.0898829	total: 9.44s	remaining: 11s
# 461:	learn: 0.0898461	total: 9.46s	remaining: 11s
# 462:	learn: 0.0898094	total: 9.48s	remaining: 11s
# 463:	learn: 0.0897843	total: 9.51s	remaining: 11s
# 464:	learn: 0.0897673	total: 9.53s	remaining: 11s
# 465:	learn: 0.0897435	total: 9.55s	remaining: 10.9s
# 466:	learn: 0.0897003	total: 9.57s	remaining: 10.9s
# 467:	learn: 0.0896840	total: 9.59s	remaining: 10.9s
# 468:	learn: 0.0896325	total: 9.61s	remaining: 10.9s
# 469:	learn: 0.0896028	total: 9.63s	remaining: 10.9s
# 470:	learn: 0.0895526	total: 9.65s	remaining: 10.8s
# 471:	learn: 0.0895239	total: 9.67s	remaining: 10.8s
# 472:	learn: 0.0894878	total: 9.69s	remaining: 10.8s
# 473:	learn: 0.0894661	total: 9.72s	remaining: 10.8s
# 474:	learn: 0.0894537	total: 9.74s	remaining: 10.8s
# 475:	learn: 0.0894365	total: 9.76s	remaining: 10.7s
# 476:	learn: 0.0894042	total: 9.78s	remaining: 10.7s
# 477:	learn: 0.0893758	total: 9.8s	remaining: 10.7s
# 478:	learn: 0.0893472	total: 9.83s	remaining: 10.7s
# 479:	learn: 0.0893028	total: 9.85s	remaining: 10.7s
# 480:	learn: 0.0892750	total: 9.87s	remaining: 10.6s
# 481:	learn: 0.0892532	total: 9.88s	remaining: 10.6s
# 482:	learn: 0.0892177	total: 9.91s	remaining: 10.6s
# 483:	learn: 0.0892078	total: 9.92s	remaining: 10.6s
# 484:	learn: 0.0891684	total: 9.95s	remaining: 10.6s
# 485:	learn: 0.0891331	total: 9.97s	remaining: 10.5s
# 486:	learn: 0.0891113	total: 9.99s	remaining: 10.5s
# 487:	learn: 0.0890889	total: 10s	remaining: 10.5s
# 488:	learn: 0.0890523	total: 10s	remaining: 10.5s
# 489:	learn: 0.0890090	total: 10.1s	remaining: 10.5s
# 490:	learn: 0.0889788	total: 10.1s	remaining: 10.4s
# 491:	learn: 0.0889135	total: 10.1s	remaining: 10.4s
# 492:	learn: 0.0889011	total: 10.1s	remaining: 10.4s
# 493:	learn: 0.0888645	total: 10.1s	remaining: 10.4s
# 494:	learn: 0.0888383	total: 10.1s	remaining: 10.3s
# 495:	learn: 0.0888141	total: 10.2s	remaining: 10.3s
# 496:	learn: 0.0887786	total: 10.2s	remaining: 10.3s
# 497:	learn: 0.0887543	total: 10.2s	remaining: 10.3s
# 498:	learn: 0.0887214	total: 10.2s	remaining: 10.3s
# 499:	learn: 0.0886888	total: 10.2s	remaining: 10.2s
# 500:	learn: 0.0886543	total: 10.2s	remaining: 10.2s
# 501:	learn: 0.0886372	total: 10.3s	remaining: 10.2s
# 502:	learn: 0.0886006	total: 10.3s	remaining: 10.2s
# 503:	learn: 0.0885756	total: 10.3s	remaining: 10.1s
# 504:	learn: 0.0885162	total: 10.3s	remaining: 10.1s
# 505:	learn: 0.0884746	total: 10.3s	remaining: 10.1s
# 506:	learn: 0.0884364	total: 10.4s	remaining: 10.1s
# 507:	learn: 0.0884220	total: 10.4s	remaining: 10s
# 508:	learn: 0.0883737	total: 10.4s	remaining: 10s
# 509:	learn: 0.0883495	total: 10.4s	remaining: 10s
# 510:	learn: 0.0883353	total: 10.4s	remaining: 9.98s
# 511:	learn: 0.0882900	total: 10.5s	remaining: 9.96s
# 512:	learn: 0.0882700	total: 10.5s	remaining: 9.94s
# 513:	learn: 0.0882224	total: 10.5s	remaining: 9.93s
# 514:	learn: 0.0881913	total: 10.5s	remaining: 9.91s
# 515:	learn: 0.0881616	total: 10.5s	remaining: 9.89s
# 516:	learn: 0.0881299	total: 10.6s	remaining: 9.87s
# 517:	learn: 0.0881075	total: 10.6s	remaining: 9.84s
# 518:	learn: 0.0880843	total: 10.6s	remaining: 9.82s
# 519:	learn: 0.0880382	total: 10.6s	remaining: 9.8s
# 520:	learn: 0.0880240	total: 10.6s	remaining: 9.78s
# 521:	learn: 0.0879950	total: 10.7s	remaining: 9.76s
# 522:	learn: 0.0879454	total: 10.7s	remaining: 9.74s
# 523:	learn: 0.0879042	total: 10.7s	remaining: 9.72s
# 524:	learn: 0.0878679	total: 10.7s	remaining: 9.7s
# 525:	learn: 0.0878528	total: 10.7s	remaining: 9.67s
# 526:	learn: 0.0878294	total: 10.8s	remaining: 9.65s
# 527:	learn: 0.0877872	total: 10.8s	remaining: 9.63s
# 528:	learn: 0.0877556	total: 10.8s	remaining: 9.61s
# 529:	learn: 0.0877181	total: 10.8s	remaining: 9.59s
# 530:	learn: 0.0876800	total: 10.8s	remaining: 9.57s
# 531:	learn: 0.0876665	total: 10.9s	remaining: 9.55s
# 532:	learn: 0.0876516	total: 10.9s	remaining: 9.52s
# 533:	learn: 0.0876108	total: 10.9s	remaining: 9.5s
# 534:	learn: 0.0875677	total: 10.9s	remaining: 9.48s
# 535:	learn: 0.0875586	total: 10.9s	remaining: 9.46s
# 536:	learn: 0.0875244	total: 10.9s	remaining: 9.44s
# 537:	learn: 0.0875000	total: 11s	remaining: 9.41s
# 538:	learn: 0.0874652	total: 11s	remaining: 9.39s
# 539:	learn: 0.0874286	total: 11s	remaining: 9.37s
# 540:	learn: 0.0873861	total: 11s	remaining: 9.35s
# 541:	learn: 0.0873512	total: 11s	remaining: 9.33s
# 542:	learn: 0.0873126	total: 11.1s	remaining: 9.3s
# 543:	learn: 0.0872957	total: 11.1s	remaining: 9.28s
# 544:	learn: 0.0872740	total: 11.1s	remaining: 9.26s
# 545:	learn: 0.0872505	total: 11.1s	remaining: 9.23s
# 546:	learn: 0.0872282	total: 11.1s	remaining: 9.21s
# 547:	learn: 0.0871978	total: 11.1s	remaining: 9.19s
# 548:	learn: 0.0871671	total: 11.2s	remaining: 9.17s
# 549:	learn: 0.0871460	total: 11.2s	remaining: 9.15s
# 550:	learn: 0.0871226	total: 11.2s	remaining: 9.12s
# 551:	learn: 0.0870885	total: 11.2s	remaining: 9.1s
# 552:	learn: 0.0870533	total: 11.2s	remaining: 9.08s
# 553:	learn: 0.0869975	total: 11.3s	remaining: 9.06s
# 554:	learn: 0.0869709	total: 11.3s	remaining: 9.04s
# 555:	learn: 0.0869417	total: 11.3s	remaining: 9.02s
# 556:	learn: 0.0869194	total: 11.3s	remaining: 9s
# 557:	learn: 0.0869015	total: 11.3s	remaining: 8.97s
# 558:	learn: 0.0868548	total: 11.3s	remaining: 8.95s
# 559:	learn: 0.0868130	total: 11.4s	remaining: 8.93s
# 560:	learn: 0.0867925	total: 11.4s	remaining: 8.91s
# 561:	learn: 0.0867582	total: 11.4s	remaining: 8.88s
# 562:	learn: 0.0867292	total: 11.4s	remaining: 8.86s
# 563:	learn: 0.0866855	total: 11.4s	remaining: 8.84s
# 564:	learn: 0.0866467	total: 11.5s	remaining: 8.82s
# 565:	learn: 0.0866293	total: 11.5s	remaining: 8.79s
# 566:	learn: 0.0865919	total: 11.5s	remaining: 8.77s
# 567:	learn: 0.0865636	total: 11.5s	remaining: 8.75s
# 568:	learn: 0.0865349	total: 11.5s	remaining: 8.72s
# 569:	learn: 0.0865037	total: 11.5s	remaining: 8.7s
# 570:	learn: 0.0864943	total: 11.6s	remaining: 8.68s
# 571:	learn: 0.0864475	total: 11.6s	remaining: 8.66s
# 572:	learn: 0.0864069	total: 11.6s	remaining: 8.64s
# 573:	learn: 0.0863603	total: 11.6s	remaining: 8.62s
# 574:	learn: 0.0863430	total: 11.6s	remaining: 8.59s
# 575:	learn: 0.0863283	total: 11.6s	remaining: 8.57s
# 576:	learn: 0.0862838	total: 11.7s	remaining: 8.55s
# 577:	learn: 0.0862763	total: 11.7s	remaining: 8.53s
# 578:	learn: 0.0862633	total: 11.7s	remaining: 8.5s
# 579:	learn: 0.0862360	total: 11.7s	remaining: 8.48s
# 580:	learn: 0.0861643	total: 11.7s	remaining: 8.47s
# 581:	learn: 0.0861446	total: 11.8s	remaining: 8.45s
# 582:	learn: 0.0861170	total: 11.8s	remaining: 8.42s
# 583:	learn: 0.0861008	total: 11.8s	remaining: 8.4s
# 584:	learn: 0.0860699	total: 11.8s	remaining: 8.38s
# 585:	learn: 0.0860382	total: 11.8s	remaining: 8.36s
# 586:	learn: 0.0860309	total: 11.8s	remaining: 8.33s
# 587:	learn: 0.0860076	total: 11.9s	remaining: 8.31s
# 588:	learn: 0.0859756	total: 11.9s	remaining: 8.29s
# 589:	learn: 0.0859161	total: 11.9s	remaining: 8.27s
# 590:	learn: 0.0859089	total: 11.9s	remaining: 8.25s
# 591:	learn: 0.0858684	total: 11.9s	remaining: 8.23s
# 592:	learn: 0.0858454	total: 12s	remaining: 8.21s
# 593:	learn: 0.0858229	total: 12s	remaining: 8.19s
# 594:	learn: 0.0857853	total: 12s	remaining: 8.16s
# 595:	learn: 0.0857509	total: 12s	remaining: 8.14s
# 596:	learn: 0.0857270	total: 12s	remaining: 8.12s
# 597:	learn: 0.0857032	total: 12s	remaining: 8.1s
# 598:	learn: 0.0856648	total: 12.1s	remaining: 8.08s
# 599:	learn: 0.0856492	total: 12.1s	remaining: 8.05s
# 600:	learn: 0.0856275	total: 12.1s	remaining: 8.03s
# 601:	learn: 0.0855990	total: 12.1s	remaining: 8.01s
# 602:	learn: 0.0855683	total: 12.1s	remaining: 7.99s
# 603:	learn: 0.0855426	total: 12.2s	remaining: 7.97s
# 604:	learn: 0.0854939	total: 12.2s	remaining: 7.95s
# 605:	learn: 0.0854537	total: 12.2s	remaining: 7.93s
# 606:	learn: 0.0854262	total: 12.2s	remaining: 7.91s
# 607:	learn: 0.0854007	total: 12.2s	remaining: 7.89s
# 608:	learn: 0.0853950	total: 12.3s	remaining: 7.87s
# 609:	learn: 0.0853735	total: 12.3s	remaining: 7.85s
# 610:	learn: 0.0853488	total: 12.3s	remaining: 7.83s
# 611:	learn: 0.0853137	total: 12.3s	remaining: 7.81s
# 612:	learn: 0.0852708	total: 12.3s	remaining: 7.79s
# 613:	learn: 0.0852519	total: 12.3s	remaining: 7.76s
# 614:	learn: 0.0852158	total: 12.4s	remaining: 7.74s
# 615:	learn: 0.0851818	total: 12.4s	remaining: 7.72s
# 616:	learn: 0.0851454	total: 12.4s	remaining: 7.7s
# 617:	learn: 0.0851344	total: 12.4s	remaining: 7.68s
# 618:	learn: 0.0851150	total: 12.4s	remaining: 7.65s
# 619:	learn: 0.0850797	total: 12.5s	remaining: 7.63s
# 620:	learn: 0.0850395	total: 12.5s	remaining: 7.61s
# 621:	learn: 0.0850210	total: 12.5s	remaining: 7.59s
# 622:	learn: 0.0849872	total: 12.5s	remaining: 7.57s
# 623:	learn: 0.0849308	total: 12.5s	remaining: 7.55s
# 624:	learn: 0.0848829	total: 12.5s	remaining: 7.53s
# 625:	learn: 0.0848755	total: 12.6s	remaining: 7.5s
# 626:	learn: 0.0848569	total: 12.6s	remaining: 7.48s
# 627:	learn: 0.0848183	total: 12.6s	remaining: 7.46s
# 628:	learn: 0.0848003	total: 12.6s	remaining: 7.44s
# 629:	learn: 0.0847807	total: 12.6s	remaining: 7.42s
# 630:	learn: 0.0847466	total: 12.6s	remaining: 7.4s
# 631:	learn: 0.0847258	total: 12.7s	remaining: 7.38s
# 632:	learn: 0.0846987	total: 12.7s	remaining: 7.36s
# 633:	learn: 0.0846747	total: 12.7s	remaining: 7.33s
# 634:	learn: 0.0846601	total: 12.7s	remaining: 7.31s
# 635:	learn: 0.0846342	total: 12.7s	remaining: 7.29s
# 636:	learn: 0.0846202	total: 12.8s	remaining: 7.27s
# 637:	learn: 0.0845646	total: 12.8s	remaining: 7.25s
# 638:	learn: 0.0845466	total: 12.8s	remaining: 7.23s
# 639:	learn: 0.0844997	total: 12.8s	remaining: 7.21s
# 640:	learn: 0.0844644	total: 12.8s	remaining: 7.18s
# 641:	learn: 0.0844313	total: 12.8s	remaining: 7.17s
# 642:	learn: 0.0844097	total: 12.9s	remaining: 7.14s
# 643:	learn: 0.0843727	total: 12.9s	remaining: 7.12s
# 644:	learn: 0.0843448	total: 12.9s	remaining: 7.1s
# 645:	learn: 0.0843183	total: 12.9s	remaining: 7.08s
# 646:	learn: 0.0842937	total: 12.9s	remaining: 7.06s
# 647:	learn: 0.0842622	total: 13s	remaining: 7.04s
# 648:	learn: 0.0842155	total: 13s	remaining: 7.03s
# 649:	learn: 0.0842073	total: 13s	remaining: 7.01s
# 650:	learn: 0.0841675	total: 13s	remaining: 7s
# 651:	learn: 0.0841503	total: 13.1s	remaining: 6.98s
# 652:	learn: 0.0841405	total: 13.1s	remaining: 6.95s
# 653:	learn: 0.0841238	total: 13.1s	remaining: 6.93s
# 654:	learn: 0.0840899	total: 13.1s	remaining: 6.91s
# 655:	learn: 0.0840792	total: 13.1s	remaining: 6.89s
# 656:	learn: 0.0840458	total: 13.2s	remaining: 6.87s
# 657:	learn: 0.0840223	total: 13.2s	remaining: 6.84s
# 658:	learn: 0.0839784	total: 13.2s	remaining: 6.83s
# 659:	learn: 0.0839422	total: 13.2s	remaining: 6.8s
# 660:	learn: 0.0839067	total: 13.2s	remaining: 6.79s
# 661:	learn: 0.0838954	total: 13.3s	remaining: 6.78s
# 662:	learn: 0.0838653	total: 13.3s	remaining: 6.76s
# 663:	learn: 0.0838348	total: 13.3s	remaining: 6.74s
# 664:	learn: 0.0837906	total: 13.3s	remaining: 6.72s
# 665:	learn: 0.0837714	total: 13.3s	remaining: 6.69s
# 666:	learn: 0.0837511	total: 13.4s	remaining: 6.67s
# 667:	learn: 0.0837162	total: 13.4s	remaining: 6.65s
# 668:	learn: 0.0836944	total: 13.4s	remaining: 6.63s
# 669:	learn: 0.0836629	total: 13.4s	remaining: 6.61s
# 670:	learn: 0.0836200	total: 13.4s	remaining: 6.59s
# 671:	learn: 0.0836040	total: 13.5s	remaining: 6.57s
# 672:	learn: 0.0835928	total: 13.5s	remaining: 6.55s
# 673:	learn: 0.0835680	total: 13.5s	remaining: 6.53s
# 674:	learn: 0.0835618	total: 13.5s	remaining: 6.51s
# 675:	learn: 0.0835475	total: 13.5s	remaining: 6.49s
# 676:	learn: 0.0835375	total: 13.6s	remaining: 6.46s
# 677:	learn: 0.0835264	total: 13.6s	remaining: 6.44s
# 678:	learn: 0.0834910	total: 13.6s	remaining: 6.42s
# 679:	learn: 0.0834802	total: 13.6s	remaining: 6.4s
# 680:	learn: 0.0834362	total: 13.6s	remaining: 6.38s
# 681:	learn: 0.0834144	total: 13.6s	remaining: 6.36s
# 682:	learn: 0.0833930	total: 13.7s	remaining: 6.34s
# 683:	learn: 0.0833696	total: 13.7s	remaining: 6.32s
# 684:	learn: 0.0833360	total: 13.7s	remaining: 6.3s
# 685:	learn: 0.0833303	total: 13.7s	remaining: 6.28s
# 686:	learn: 0.0833142	total: 13.7s	remaining: 6.25s
# 687:	learn: 0.0833053	total: 13.7s	remaining: 6.23s
# 688:	learn: 0.0832889	total: 13.8s	remaining: 6.21s
# 689:	learn: 0.0832590	total: 13.8s	remaining: 6.19s
# 690:	learn: 0.0832284	total: 13.8s	remaining: 6.17s
# 691:	learn: 0.0832083	total: 13.8s	remaining: 6.15s
# 692:	learn: 0.0831995	total: 13.8s	remaining: 6.13s
# 693:	learn: 0.0831671	total: 13.8s	remaining: 6.11s
# 694:	learn: 0.0831509	total: 13.9s	remaining: 6.08s
# 695:	learn: 0.0831414	total: 13.9s	remaining: 6.07s
# 696:	learn: 0.0831241	total: 13.9s	remaining: 6.04s
# 697:	learn: 0.0830984	total: 13.9s	remaining: 6.03s
# 698:	learn: 0.0830750	total: 13.9s	remaining: 6s
# 699:	learn: 0.0830431	total: 14s	remaining: 5.99s
# 700:	learn: 0.0830058	total: 14s	remaining: 5.96s
# 701:	learn: 0.0829930	total: 14s	remaining: 5.94s
# 702:	learn: 0.0829490	total: 14s	remaining: 5.92s
# 703:	learn: 0.0829362	total: 14s	remaining: 5.9s
# 704:	learn: 0.0829130	total: 14.1s	remaining: 5.88s
# 705:	learn: 0.0829052	total: 14.1s	remaining: 5.86s
# 706:	learn: 0.0829003	total: 14.1s	remaining: 5.84s
# 707:	learn: 0.0828738	total: 14.1s	remaining: 5.82s
# 708:	learn: 0.0828473	total: 14.1s	remaining: 5.8s
# 709:	learn: 0.0828220	total: 14.1s	remaining: 5.78s
# 710:	learn: 0.0828141	total: 14.2s	remaining: 5.75s
# 711:	learn: 0.0827753	total: 14.2s	remaining: 5.73s
# 712:	learn: 0.0827488	total: 14.2s	remaining: 5.71s
# 713:	learn: 0.0827274	total: 14.2s	remaining: 5.69s
# 714:	learn: 0.0827021	total: 14.2s	remaining: 5.67s
# 715:	learn: 0.0826761	total: 14.2s	remaining: 5.65s
# 716:	learn: 0.0826449	total: 14.3s	remaining: 5.63s
# 717:	learn: 0.0826220	total: 14.3s	remaining: 5.61s
# 718:	learn: 0.0825953	total: 14.3s	remaining: 5.59s
# 719:	learn: 0.0825881	total: 14.3s	remaining: 5.57s
# 720:	learn: 0.0825740	total: 14.3s	remaining: 5.55s
# 721:	learn: 0.0825365	total: 14.4s	remaining: 5.53s
# 722:	learn: 0.0825043	total: 14.4s	remaining: 5.51s
# 723:	learn: 0.0824689	total: 14.4s	remaining: 5.49s
# 724:	learn: 0.0824415	total: 14.4s	remaining: 5.47s
# 725:	learn: 0.0824030	total: 14.4s	remaining: 5.44s
# 726:	learn: 0.0823709	total: 14.4s	remaining: 5.42s
# 727:	learn: 0.0823407	total: 14.5s	remaining: 5.4s
# 728:	learn: 0.0823073	total: 14.5s	remaining: 5.38s
# 729:	learn: 0.0822757	total: 14.5s	remaining: 5.37s
# 730:	learn: 0.0822339	total: 14.5s	remaining: 5.34s
# 731:	learn: 0.0822215	total: 14.5s	remaining: 5.32s
# 732:	learn: 0.0821927	total: 14.6s	remaining: 5.3s
# 733:	learn: 0.0821781	total: 14.6s	remaining: 5.28s
# 734:	learn: 0.0821560	total: 14.6s	remaining: 5.26s
# 735:	learn: 0.0821441	total: 14.6s	remaining: 5.24s
# 736:	learn: 0.0821126	total: 14.6s	remaining: 5.22s
# 737:	learn: 0.0820853	total: 14.6s	remaining: 5.2s
# 738:	learn: 0.0820350	total: 14.7s	remaining: 5.18s
# 739:	learn: 0.0819955	total: 14.7s	remaining: 5.16s
# 740:	learn: 0.0819552	total: 14.7s	remaining: 5.14s
# 741:	learn: 0.0819213	total: 14.7s	remaining: 5.12s
# 742:	learn: 0.0819011	total: 14.7s	remaining: 5.1s
# 743:	learn: 0.0818388	total: 14.8s	remaining: 5.08s
# 744:	learn: 0.0818051	total: 14.8s	remaining: 5.06s
# 745:	learn: 0.0817880	total: 14.8s	remaining: 5.04s
# 746:	learn: 0.0817570	total: 14.8s	remaining: 5.02s
# 747:	learn: 0.0817261	total: 14.8s	remaining: 5s
# 748:	learn: 0.0816957	total: 14.9s	remaining: 4.98s
# 749:	learn: 0.0816843	total: 14.9s	remaining: 4.96s
# 750:	learn: 0.0816544	total: 14.9s	remaining: 4.94s
# 751:	learn: 0.0816262	total: 14.9s	remaining: 4.92s
# 752:	learn: 0.0815859	total: 14.9s	remaining: 4.9s
# 753:	learn: 0.0815729	total: 15s	remaining: 4.88s
# 754:	learn: 0.0815557	total: 15s	remaining: 4.86s
# 755:	learn: 0.0815244	total: 15s	remaining: 4.84s
# 756:	learn: 0.0814968	total: 15s	remaining: 4.82s
# 757:	learn: 0.0814867	total: 15s	remaining: 4.8s
# 758:	learn: 0.0814810	total: 15s	remaining: 4.78s
# 759:	learn: 0.0814555	total: 15.1s	remaining: 4.75s
# 760:	learn: 0.0814036	total: 15.1s	remaining: 4.74s
# 761:	learn: 0.0813987	total: 15.1s	remaining: 4.71s
# 762:	learn: 0.0813549	total: 15.1s	remaining: 4.69s
# 763:	learn: 0.0813179	total: 15.1s	remaining: 4.67s
# 764:	learn: 0.0813099	total: 15.1s	remaining: 4.65s
# 765:	learn: 0.0813003	total: 15.2s	remaining: 4.63s
# 766:	learn: 0.0812772	total: 15.2s	remaining: 4.61s
# 767:	learn: 0.0812699	total: 15.2s	remaining: 4.59s
# 768:	learn: 0.0812244	total: 15.2s	remaining: 4.57s
# 769:	learn: 0.0812123	total: 15.2s	remaining: 4.55s
# 770:	learn: 0.0811992	total: 15.3s	remaining: 4.53s
# 771:	learn: 0.0811739	total: 15.3s	remaining: 4.51s
# 772:	learn: 0.0811403	total: 15.3s	remaining: 4.5s
# 773:	learn: 0.0811019	total: 15.3s	remaining: 4.47s
# 774:	learn: 0.0810617	total: 15.3s	remaining: 4.46s
# 775:	learn: 0.0810415	total: 15.4s	remaining: 4.44s
# 776:	learn: 0.0810108	total: 15.4s	remaining: 4.42s
# 777:	learn: 0.0809921	total: 15.4s	remaining: 4.4s
# 778:	learn: 0.0809601	total: 15.4s	remaining: 4.38s
# 779:	learn: 0.0809302	total: 15.5s	remaining: 4.36s
# 780:	learn: 0.0808882	total: 15.5s	remaining: 4.34s
# 781:	learn: 0.0808647	total: 15.5s	remaining: 4.32s
# 782:	learn: 0.0808477	total: 15.5s	remaining: 4.3s
# 783:	learn: 0.0808213	total: 15.5s	remaining: 4.28s
# 784:	learn: 0.0807675	total: 15.6s	remaining: 4.26s
# 785:	learn: 0.0807545	total: 15.6s	remaining: 4.24s
# 786:	learn: 0.0807262	total: 15.6s	remaining: 4.22s
# 787:	learn: 0.0806744	total: 15.6s	remaining: 4.2s
# 788:	learn: 0.0806581	total: 15.6s	remaining: 4.18s
# 789:	learn: 0.0806295	total: 15.7s	remaining: 4.16s
# 790:	learn: 0.0805990	total: 15.7s	remaining: 4.14s
# 791:	learn: 0.0805667	total: 15.7s	remaining: 4.12s
# 792:	learn: 0.0805396	total: 15.7s	remaining: 4.1s
# 793:	learn: 0.0805019	total: 15.7s	remaining: 4.08s
# 794:	learn: 0.0804732	total: 15.8s	remaining: 4.06s
# 795:	learn: 0.0804537	total: 15.8s	remaining: 4.04s
# 796:	learn: 0.0804100	total: 15.8s	remaining: 4.03s
# 797:	learn: 0.0803833	total: 15.8s	remaining: 4s
# 798:	learn: 0.0803593	total: 15.8s	remaining: 3.99s
# 799:	learn: 0.0803518	total: 15.9s	remaining: 3.96s
# 800:	learn: 0.0803262	total: 15.9s	remaining: 3.94s
# 801:	learn: 0.0803110	total: 15.9s	remaining: 3.92s
# 802:	learn: 0.0802973	total: 15.9s	remaining: 3.9s
# 803:	learn: 0.0802699	total: 15.9s	remaining: 3.88s
# 804:	learn: 0.0802630	total: 16s	remaining: 3.87s
# 805:	learn: 0.0802183	total: 16s	remaining: 3.84s
# 806:	learn: 0.0801954	total: 16s	remaining: 3.82s
# 807:	learn: 0.0801834	total: 16s	remaining: 3.8s
# 808:	learn: 0.0801733	total: 16s	remaining: 3.78s
# 809:	learn: 0.0801537	total: 16s	remaining: 3.76s
# 810:	learn: 0.0801211	total: 16.1s	remaining: 3.74s
# 811:	learn: 0.0800992	total: 16.1s	remaining: 3.72s
# 812:	learn: 0.0800807	total: 16.1s	remaining: 3.7s
# 813:	learn: 0.0800662	total: 16.1s	remaining: 3.68s
# 814:	learn: 0.0800342	total: 16.1s	remaining: 3.66s
# 815:	learn: 0.0799986	total: 16.2s	remaining: 3.64s
# 816:	learn: 0.0799950	total: 16.2s	remaining: 3.62s
# 817:	learn: 0.0799608	total: 16.2s	remaining: 3.6s
# 818:	learn: 0.0799389	total: 16.2s	remaining: 3.58s
# 819:	learn: 0.0799281	total: 16.2s	remaining: 3.56s
# 820:	learn: 0.0798912	total: 16.2s	remaining: 3.54s
# 821:	learn: 0.0798600	total: 16.3s	remaining: 3.52s
# 822:	learn: 0.0798042	total: 16.3s	remaining: 3.5s
# 823:	learn: 0.0797825	total: 16.3s	remaining: 3.48s
# 824:	learn: 0.0797700	total: 16.3s	remaining: 3.46s
# 825:	learn: 0.0797450	total: 16.3s	remaining: 3.44s
# 826:	learn: 0.0797196	total: 16.4s	remaining: 3.42s
# 827:	learn: 0.0796943	total: 16.4s	remaining: 3.4s
# 828:	learn: 0.0796382	total: 16.4s	remaining: 3.38s
# 829:	learn: 0.0796090	total: 16.4s	remaining: 3.36s
# 830:	learn: 0.0795857	total: 16.4s	remaining: 3.34s
# 831:	learn: 0.0795775	total: 16.5s	remaining: 3.32s
# 832:	learn: 0.0795607	total: 16.5s	remaining: 3.3s
# 833:	learn: 0.0795288	total: 16.5s	remaining: 3.28s
# 834:	learn: 0.0795110	total: 16.5s	remaining: 3.26s
# 835:	learn: 0.0794996	total: 16.5s	remaining: 3.24s
# 836:	learn: 0.0794930	total: 16.5s	remaining: 3.22s
# 837:	learn: 0.0794757	total: 16.6s	remaining: 3.2s
# 838:	learn: 0.0794605	total: 16.6s	remaining: 3.18s
# 839:	learn: 0.0794010	total: 16.6s	remaining: 3.16s
# 840:	learn: 0.0793725	total: 16.6s	remaining: 3.14s
# 841:	learn: 0.0793466	total: 16.6s	remaining: 3.12s
# 842:	learn: 0.0793123	total: 16.6s	remaining: 3.1s
# 843:	learn: 0.0792834	total: 16.7s	remaining: 3.08s
# 844:	learn: 0.0792632	total: 16.7s	remaining: 3.06s
# 845:	learn: 0.0792369	total: 16.7s	remaining: 3.04s
# 846:	learn: 0.0792186	total: 16.7s	remaining: 3.02s
# 847:	learn: 0.0791796	total: 16.7s	remaining: 3s
# 848:	learn: 0.0791668	total: 16.8s	remaining: 2.98s
# 849:	learn: 0.0791412	total: 16.8s	remaining: 2.96s
# 850:	learn: 0.0791260	total: 16.8s	remaining: 2.94s
# 851:	learn: 0.0790949	total: 16.8s	remaining: 2.92s
# 852:	learn: 0.0790882	total: 16.8s	remaining: 2.9s
# 853:	learn: 0.0790712	total: 16.9s	remaining: 2.88s
# 854:	learn: 0.0790398	total: 16.9s	remaining: 2.86s
# 855:	learn: 0.0790154	total: 16.9s	remaining: 2.84s
# 856:	learn: 0.0789900	total: 16.9s	remaining: 2.82s
# 857:	learn: 0.0789664	total: 16.9s	remaining: 2.8s
# 858:	learn: 0.0789451	total: 16.9s	remaining: 2.78s
# 859:	learn: 0.0789241	total: 17s	remaining: 2.76s
# 860:	learn: 0.0789055	total: 17s	remaining: 2.74s
# 861:	learn: 0.0788621	total: 17s	remaining: 2.72s
# 862:	learn: 0.0788601	total: 17s	remaining: 2.7s
# 863:	learn: 0.0788484	total: 17s	remaining: 2.68s
# 864:	learn: 0.0788255	total: 17.1s	remaining: 2.66s
# 865:	learn: 0.0788028	total: 17.1s	remaining: 2.64s
# 866:	learn: 0.0787625	total: 17.1s	remaining: 2.62s
# 867:	learn: 0.0787255	total: 17.1s	remaining: 2.6s
# 868:	learn: 0.0787215	total: 17.1s	remaining: 2.58s
# 869:	learn: 0.0787079	total: 17.1s	remaining: 2.56s
# 870:	learn: 0.0786955	total: 17.2s	remaining: 2.54s
# 871:	learn: 0.0786887	total: 17.2s	remaining: 2.52s
# 872:	learn: 0.0786693	total: 17.2s	remaining: 2.5s
# 873:	learn: 0.0786415	total: 17.2s	remaining: 2.48s
# 874:	learn: 0.0786219	total: 17.2s	remaining: 2.46s
# 875:	learn: 0.0785888	total: 17.3s	remaining: 2.44s
# 876:	learn: 0.0785677	total: 17.3s	remaining: 2.42s
# 877:	learn: 0.0785371	total: 17.3s	remaining: 2.4s
# 878:	learn: 0.0785096	total: 17.3s	remaining: 2.38s
# 879:	learn: 0.0784655	total: 17.3s	remaining: 2.36s
# 880:	learn: 0.0784385	total: 17.3s	remaining: 2.34s
# 881:	learn: 0.0784208	total: 17.4s	remaining: 2.32s
# 882:	learn: 0.0783923	total: 17.4s	remaining: 2.3s
# 883:	learn: 0.0783420	total: 17.4s	remaining: 2.28s
# 884:	learn: 0.0783366	total: 17.4s	remaining: 2.26s
# 885:	learn: 0.0783249	total: 17.4s	remaining: 2.24s
# 886:	learn: 0.0782903	total: 17.5s	remaining: 2.22s
# 887:	learn: 0.0782858	total: 17.5s	remaining: 2.2s
# 888:	learn: 0.0782654	total: 17.5s	remaining: 2.18s
# 889:	learn: 0.0782264	total: 17.5s	remaining: 2.16s
# 890:	learn: 0.0782133	total: 17.5s	remaining: 2.14s
# 891:	learn: 0.0781988	total: 17.5s	remaining: 2.12s
# 892:	learn: 0.0781755	total: 17.6s	remaining: 2.1s
# 893:	learn: 0.0781455	total: 17.6s	remaining: 2.08s
# 894:	learn: 0.0781193	total: 17.6s	remaining: 2.06s
# 895:	learn: 0.0781012	total: 17.6s	remaining: 2.04s
# 896:	learn: 0.0780874	total: 17.6s	remaining: 2.02s
# 897:	learn: 0.0780593	total: 17.7s	remaining: 2s
# 898:	learn: 0.0780372	total: 17.7s	remaining: 1.99s
# 899:	learn: 0.0780134	total: 17.7s	remaining: 1.97s
# 900:	learn: 0.0779882	total: 17.7s	remaining: 1.95s
# 901:	learn: 0.0779724	total: 17.7s	remaining: 1.93s
# 902:	learn: 0.0779573	total: 17.7s	remaining: 1.91s
# 903:	learn: 0.0779368	total: 17.8s	remaining: 1.89s
# 904:	learn: 0.0778995	total: 17.8s	remaining: 1.87s
# 905:	learn: 0.0778995	total: 17.8s	remaining: 1.85s
# 906:	learn: 0.0778939	total: 17.8s	remaining: 1.83s
# 907:	learn: 0.0778603	total: 17.8s	remaining: 1.81s
# 908:	learn: 0.0778557	total: 17.8s	remaining: 1.79s
# 909:	learn: 0.0778395	total: 17.9s	remaining: 1.77s
# 910:	learn: 0.0778125	total: 17.9s	remaining: 1.75s
# 911:	learn: 0.0778093	total: 17.9s	remaining: 1.73s
# 912:	learn: 0.0777930	total: 17.9s	remaining: 1.71s
# 913:	learn: 0.0777579	total: 17.9s	remaining: 1.69s
# 914:	learn: 0.0777292	total: 17.9s	remaining: 1.67s
# 915:	learn: 0.0777096	total: 18s	remaining: 1.65s
# 916:	learn: 0.0776923	total: 18s	remaining: 1.63s
# 917:	learn: 0.0776674	total: 18s	remaining: 1.61s
# 918:	learn: 0.0776419	total: 18s	remaining: 1.59s
# 919:	learn: 0.0776156	total: 18s	remaining: 1.57s
# 920:	learn: 0.0775893	total: 18.1s	remaining: 1.55s
# 921:	learn: 0.0775608	total: 18.1s	remaining: 1.53s
# 922:	learn: 0.0775558	total: 18.1s	remaining: 1.51s
# 923:	learn: 0.0775420	total: 18.1s	remaining: 1.49s
# 924:	learn: 0.0775223	total: 18.1s	remaining: 1.47s
# 925:	learn: 0.0774921	total: 18.1s	remaining: 1.45s
# 926:	learn: 0.0774523	total: 18.2s	remaining: 1.43s
# 927:	learn: 0.0774420	total: 18.2s	remaining: 1.41s
# 928:	learn: 0.0774097	total: 18.2s	remaining: 1.39s
# 929:	learn: 0.0773807	total: 18.2s	remaining: 1.37s
# 930:	learn: 0.0773629	total: 18.3s	remaining: 1.35s
# 931:	learn: 0.0773495	total: 18.3s	remaining: 1.33s
# 932:	learn: 0.0773139	total: 18.3s	remaining: 1.31s
# 933:	learn: 0.0772973	total: 18.3s	remaining: 1.29s
# 934:	learn: 0.0772658	total: 18.3s	remaining: 1.27s
# 935:	learn: 0.0772507	total: 18.4s	remaining: 1.25s
# 936:	learn: 0.0772342	total: 18.4s	remaining: 1.24s
# 937:	learn: 0.0772257	total: 18.4s	remaining: 1.22s
# 938:	learn: 0.0771932	total: 18.4s	remaining: 1.2s
# 939:	learn: 0.0771561	total: 18.4s	remaining: 1.18s
# 940:	learn: 0.0771270	total: 18.5s	remaining: 1.16s
# 941:	learn: 0.0770959	total: 18.5s	remaining: 1.14s
# 942:	learn: 0.0770822	total: 18.5s	remaining: 1.12s
# 943:	learn: 0.0770321	total: 18.5s	remaining: 1.1s
# 944:	learn: 0.0770028	total: 18.5s	remaining: 1.08s
# 945:	learn: 0.0769730	total: 18.6s	remaining: 1.06s
# 946:	learn: 0.0769462	total: 18.6s	remaining: 1.04s
# 947:	learn: 0.0769198	total: 18.6s	remaining: 1.02s
# 948:	learn: 0.0768879	total: 18.6s	remaining: 1s
# 949:	learn: 0.0768813	total: 18.7s	remaining: 982ms
# 950:	learn: 0.0768585	total: 18.7s	remaining: 963ms
# 951:	learn: 0.0768383	total: 18.7s	remaining: 943ms
# 952:	learn: 0.0768026	total: 18.7s	remaining: 923ms
# 953:	learn: 0.0767681	total: 18.7s	remaining: 903ms
# 954:	learn: 0.0767454	total: 18.8s	remaining: 884ms
# 955:	learn: 0.0767414	total: 18.8s	remaining: 864ms
# 956:	learn: 0.0767049	total: 18.8s	remaining: 845ms
# 957:	learn: 0.0766811	total: 18.8s	remaining: 825ms
# 958:	learn: 0.0766624	total: 18.8s	remaining: 805ms
# 959:	learn: 0.0766432	total: 18.9s	remaining: 786ms
# 960:	learn: 0.0766208	total: 18.9s	remaining: 766ms
# 961:	learn: 0.0766099	total: 18.9s	remaining: 746ms
# 962:	learn: 0.0765822	total: 18.9s	remaining: 726ms
# 963:	learn: 0.0765695	total: 18.9s	remaining: 707ms
# 964:	learn: 0.0765470	total: 18.9s	remaining: 687ms
# 965:	learn: 0.0765233	total: 19s	remaining: 667ms
# 966:	learn: 0.0765012	total: 19s	remaining: 648ms
# 967:	learn: 0.0764805	total: 19s	remaining: 628ms
# 968:	learn: 0.0764601	total: 19s	remaining: 608ms
# 969:	learn: 0.0764142	total: 19s	remaining: 589ms
# 970:	learn: 0.0763835	total: 19s	remaining: 569ms
# 971:	learn: 0.0763597	total: 19.1s	remaining: 549ms
# 972:	learn: 0.0763260	total: 19.1s	remaining: 530ms
# 973:	learn: 0.0762891	total: 19.1s	remaining: 510ms
# 974:	learn: 0.0762595	total: 19.1s	remaining: 490ms
# 975:	learn: 0.0762338	total: 19.1s	remaining: 471ms
# 976:	learn: 0.0762169	total: 19.2s	remaining: 451ms
# 977:	learn: 0.0762033	total: 19.2s	remaining: 431ms
# 978:	learn: 0.0761710	total: 19.2s	remaining: 412ms
# 979:	learn: 0.0761567	total: 19.2s	remaining: 392ms
# 980:	learn: 0.0761205	total: 19.2s	remaining: 373ms
# 981:	learn: 0.0760803	total: 19.3s	remaining: 353ms
# 982:	learn: 0.0760572	total: 19.3s	remaining: 333ms
# 983:	learn: 0.0760307	total: 19.3s	remaining: 314ms
# 984:	learn: 0.0759994	total: 19.3s	remaining: 294ms
# 985:	learn: 0.0759809	total: 19.3s	remaining: 274ms
# 986:	learn: 0.0759631	total: 19.3s	remaining: 255ms
# 987:	learn: 0.0759312	total: 19.4s	remaining: 235ms
# 988:	learn: 0.0759096	total: 19.4s	remaining: 215ms
# 989:	learn: 0.0758827	total: 19.4s	remaining: 196ms
# 990:	learn: 0.0758668	total: 19.4s	remaining: 176ms
# 991:	learn: 0.0758440	total: 19.4s	remaining: 157ms
# 992:	learn: 0.0758233	total: 19.4s	remaining: 137ms
# 993:	learn: 0.0757998	total: 19.5s	remaining: 118ms
# 994:	learn: 0.0757715	total: 19.5s	remaining: 97.9ms
# 995:	learn: 0.0757534	total: 19.5s	remaining: 78.3ms
# 996:	learn: 0.0757312	total: 19.5s	remaining: 58.8ms
# 997:	learn: 0.0757119	total: 19.5s	remaining: 39.2ms
# 998:	learn: 0.0756901	total: 19.6s	remaining: 19.6ms
# 999:	learn: 0.0756517	total: 19.6s	remaining: 0us
# FEATRUE SELECTION
# Before  (74898, 173)
# After  (74898, 10)

# %%
X_tr_selec.columns
# Out:
# Index(['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam',
#        'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam',
#        'PalletID Collect Result_Dam', 'Production Qty Collect Result_Dam',
#        '1st Pressure Collect Result_AutoClave',
#        'PalletID Collect Result_Fill1', 'Production Qty Collect Result_Fill1',
#        'Production Qty Collect Result_Fill2', 'Receip No Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result Bins_Dam'],
#       dtype='object')

# %%
# ###############################  EVALUATION  ############################
# stk = StratifiedKFold(n_splits=10, random_state=config.seed, shuffle=True)
# rstk = RepeatedStratifiedKFold(n_splits=10, random_state=config.seed)

# if config.check_all:
#     classifiers_lst = list(classifiers.values())
#     score_df = pd.DataFrame(columns=classifiers.keys())
    
#     for clf_name, clf in classifiers.items():
#         scores = cross_val_score(clf, X_tr_selec, y_tr, scoring="f1", cv=stk)
#         print(scores)
#         score_df.loc[0, clf_name] = scores.mean()
#         print(score_df)
    
    
# else:
#     metrics = ['accuracy', 'precision', 'recall', 'f1', 'f1_weighted', 'roc_auc']
#     score_df = pd.DataFrame(columns=metrics)
    
#     for metric in metrics:
#         scores = cross_val_score(classifiers["cat"], X_tr_selec, y_tr, scoring=metric, cv=stk)
#         score_df[metric] = scores.mean()
    
# print("MODEL CHECK")
# print(score_df, end='\n')

# %%
def catboost_objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.0001, 0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_uniform('colsample_bylevel', 0.5, 1.0),
        'od_type': trial.suggest_categorical("od_type", ["IncToDec", "Iter"]),
        'od_wait': trial.suggest_int("od_wait", 10, 50),
    }

    cat_clf = CatBoostClassifier(**params, random_state=config.seed, auto_class_weights="Balanced",) # eval_metric="TotalF1"
    
    stk = StratifiedKFold(n_splits=config.k, random_state=config.seed, shuffle=True)
    f1_scores = np.empty(config.k)
    
    for idx, (tr_idx, val_idx) in enumerate(stk.split(X_tr_selec, y_tr)):
        X_tr_fold, X_val_fold = X_tr.iloc[tr_idx], X_tr.iloc[val_idx]
        y_tr_fold, y_val_fold = y_tr.iloc[tr_idx], y_tr.iloc[val_idx]
        
        cat_clf.fit(X_tr_fold, y_tr_fold, eval_set=[(X_val_fold, y_val_fold)], early_stopping_rounds=50, verbose=False)
        y_pred_fold = cat_clf.predict(X_val_fold)
        f1_scores[idx] = f1_score(y_val_fold, y_pred_fold)

    return np.mean(f1_scores)

# %%
def lgbm_objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'num_leaves': trial.suggest_int('num_leaves', 10, 1000),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
    }
    
    lgbm_clf = LGBMClassifier(**params, random_state=config.seed)
    
    stk = StratifiedKFold(n_splits=config.k, random_state=config.seed, shuffle=True)
    f1_scores = np.empty(config.k)
    
    for idx, (tr_idx, val_idx) in enumerate(stk.split(X_tr_selec, y_tr)):
        X_tr_fold, X_val_fold = X_tr_selec.iloc[tr_idx], X_tr_selec.iloc[val_idx]
        y_tr_fold, y_val_fold = y_tr.iloc[tr_idx], y_tr.iloc[val_idx]
        
        lgbm_clf.fit(X_tr_fold, y_tr_fold)
        y_pred_fold = lgbm_clf.predict(X_val_fold)
        f1_scores[idx] = f1_score(y_val_fold, y_pred_fold)

    return np.mean(f1_scores)

# %%
def xgboost_objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.0001, 0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),  # colsample_bylevel -> colsample_bytree
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),  # XGBoost의 중요한 파라미터 중 하나
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),  # 트리의 분할을 조정하는 파라미터
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),  # L1 정규화 항
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),  # L2 정규화 항
    }

    xgb_clf = XGBClassifier(**params, random_state=config.seed, use_label_encoder=False,
                            eval_metric='auc',
                            early_stopping_rounds=50, 
                            objective = "binary:logistic",)
    
    stk = StratifiedKFold(n_splits=config.k, random_state=config.seed, shuffle=True)
    f1_scores = np.empty(config.k)
    
    for idx, (tr_idx, val_idx) in enumerate(stk.split(X_tr_selec, y_tr)):
        X_tr_fold, X_val_fold = X_tr.iloc[tr_idx], X_tr.iloc[val_idx]
        y_tr_fold, y_val_fold = y_tr.iloc[tr_idx], y_tr.iloc[val_idx]
        
        xgb_clf.fit(X_tr_fold, y_tr_fold, eval_set=[(X_val_fold, y_val_fold)], early_stopping_rounds=50, verbose=False)
        y_pred_fold = xgb_clf.predict(X_val_fold)
        f1_scores[idx] = f1_score(y_val_fold, y_pred_fold)

    return np.mean(f1_scores)

# %%
# logger = logging.getLogger()
    
# logger.setLevel(logging.INFO)
# logger.addHandler(logging.FileHandler(f"./log/{config.model}_optuna.log", mode="w"))
    
# optuna.logging.enable_propagation() 
# optuna.logging.disable_default_handler()
        
sampler = NSGAIISampler(seed=config.seed)
pruner = optuna.pruners.HyperbandPruner()

if config.tune_mode and config.model == "cat":
    
    cat_study = optuna.create_study(study_name="cat", direction='maximize', sampler=sampler, pruner=pruner)
    cat_study.optimize(catboost_objective, n_trials=10)
    
    cat_best_params = cat_study.best_params
    cat_best_score = cat_study.best_value
    
    print("CatBoost Best Hyperparams: ", cat_best_params)
    print("CatBoost Best F1 Score: ", cat_best_score, end='\n')
    
    final_clf = CatBoostClassifier(**cat_best_params, random_state=config.seed, auto_class_weights="Balanced",)
    
elif config.tune_mode and config.model == "lgbm":
    
    lgbm_study = optuna.create_study(study_name="lgbm", direction='maximize', sampler=sampler, pruner=pruner)
    lgbm_study.optimize(lgbm_objective, n_trials=15)
    
    lgbm_best_params = lgbm_study.best_params
    lgbm_best_score= lgbm_study.best_value
    
    print("LGBM Best Hyperparams: ",lgbm_best_params)
    print("LGBM Best F1 Score: ", lgbm_best_score, end='\n')
    
    final_clf = LGBMClassifier(**lgbm_best_params, random_state=config.seed,)

elif config.tune_mode and config.model == "xgb":
    
    xgb_study = optuna.create_study(study_name="xgb", direction='maximize', sampler=sampler, pruner=pruner)
    xgb_study.optimize(xgboost_objective, n_trials=15)
    
    xgb_best_params = xgb_study.best_params
    xgb_best_score = xgb_study.best_value
    print("XGBoost Best Hyperparams: ", xgb_best_params)
    print("XGBoost Best F1 Score: ", xgb_best_score)
    
else:
    final_clf = classifiers[config.model]

# with open(f"./log/{config.model}_optuna.log") as f:
#     assert f.readline().startswith("A new study created")
#     assert f.readline() == "Start optimization.\n"
# Out:
# [I 2024-08-26 11:05:24,973] A new study created in memory with name: cat
# [I 2024-08-26 11:09:59,724] Trial 0 finished with value: 0.97235294558823 and parameters: {'n_estimators': 482, 'learning_rate': 0.007870322063188457, 'max_depth': 8, 'subsample': 0.7012836414644832, 'colsample_bylevel': 0.6720489300307877, 'od_type': 'Iter', 'od_wait': 14}. Best is trial 0 with value: 0.97235294558823.
# [I 2024-08-26 11:10:38,885] Trial 1 finished with value: 0.9721665179225463 and parameters: {'n_estimators': 170, 'learning_rate': 0.015314909484200338, 'max_depth': 5, 'subsample': 0.5590724561439451, 'colsample_bylevel': 0.6158019907405197, 'od_type': 'IncToDec', 'od_wait': 43}. Best is trial 0 with value: 0.97235294558823.
# [I 2024-08-26 11:12:50,441] Trial 2 finished with value: 0.9699354354751349 and parameters: {'n_estimators': 273, 'learning_rate': 0.00011578523132411305, 'max_depth': 7, 'subsample': 0.7665711157674153, 'colsample_bylevel': 0.8443308944666477, 'od_type': 'Iter', 'od_wait': 47}. Best is trial 0 with value: 0.97235294558823.
# [I 2024-08-26 11:15:25,051] Trial 3 finished with value: 0.9713378795308415 and parameters: {'n_estimators': 919, 'learning_rate': 0.002142409397851677, 'max_depth': 4, 'subsample': 0.8038874701824867, 'colsample_bylevel': 0.5551427043342803, 'od_type': 'Iter', 'od_wait': 26}. Best is trial 0 with value: 0.97235294558823.
# [I 2024-08-26 11:16:50,290] Trial 4 finished with value: 0.9721132090629754 and parameters: {'n_estimators': 742, 'learning_rate': 0.004306359280911751, 'max_depth': 3, 'subsample': 0.7428998455975369, 'colsample_bylevel': 0.7708129009288947, 'od_type': 'IncToDec', 'od_wait': 45}. Best is trial 0 with value: 0.97235294558823.
# [I 2024-08-26 11:32:36,515] Trial 5 finished with value: 0.9724063442509424 and parameters: {'n_estimators': 430, 'learning_rate': 0.005243462722264941, 'max_depth': 12, 'subsample': 0.6895655748561645, 'colsample_bylevel': 0.8522550848327523, 'od_type': 'IncToDec', 'od_wait': 18}. Best is trial 5 with value: 0.9724063442509424.
# [I 2024-08-26 11:34:24,310] Trial 6 finished with value: 0.9699354354751349 and parameters: {'n_estimators': 427, 'learning_rate': 0.0002166458201817631, 'max_depth': 6, 'subsample': 0.971544941431834, 'colsample_bylevel': 0.6039377843176147, 'od_type': 'IncToDec', 'od_wait': 28}. Best is trial 5 with value: 0.9724063442509424.
# [I 2024-08-26 11:36:47,965] Trial 7 finished with value: 0.9699354354751349 and parameters: {'n_estimators': 284, 'learning_rate': 0.001483620217334798, 'max_depth': 8, 'subsample': 0.9202011737250186, 'colsample_bylevel': 0.6975838025838077, 'od_type': 'IncToDec', 'od_wait': 35}. Best is trial 5 with value: 0.9724063442509424.
# [I 2024-08-26 11:37:56,134] Trial 8 finished with value: 0.9726997880042536 and parameters: {'n_estimators': 346, 'learning_rate': 0.05346913391764926, 'max_depth': 6, 'subsample': 0.6796526428168673, 'colsample_bylevel': 0.5344536110296659, 'od_type': 'IncToDec', 'od_wait': 41}. Best is trial 8 with value: 0.9726997880042536.
# [I 2024-08-26 11:44:34,739] Trial 9 finished with value: 0.9726465430561845 and parameters: {'n_estimators': 342, 'learning_rate': 0.033239324008570846, 'max_depth': 11, 'subsample': 0.5906259642335754, 'colsample_bylevel': 0.8925638682508388, 'od_type': 'Iter', 'od_wait': 20}. Best is trial 8 with value: 0.9726997880042536.
# CatBoost Best Hyperparams:  {'n_estimators': 346, 'learning_rate': 0.05346913391764926, 'max_depth': 6, 'subsample': 0.6796526428168673, 'colsample_bylevel': 0.5344536110296659, 'od_type': 'IncToDec', 'od_wait': 41}
# CatBoost Best F1 Score:  0.9726997880042536

# %%
X_tr_selec.columns
# Out:
# Index(['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam',
#        'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam',
#        'PalletID Collect Result_Dam', 'Production Qty Collect Result_Dam',
#        '1st Pressure Collect Result_AutoClave',
#        'PalletID Collect Result_Fill1', 'Production Qty Collect Result_Fill1',
#        'Production Qty Collect Result_Fill2', 'Receip No Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result Bins_Dam'],
#       dtype='object')

# %%
#cat_study.visualize()
#cat_study.trials_dataframe()

# %%
################################################################
#####################     SUBMISSION   #########################
################################################################
final_clf.fit(X_tr_selec, y_tr, ) # use_best_model=True
final_preds = final_clf.predict(X_te_selec)
# Out:
# 0:	learn: 0.6084276	total: 12.3ms	remaining: 4.25s
# 1:	learn: 0.5578253	total: 20.6ms	remaining: 3.54s
# 2:	learn: 0.5161744	total: 28.4ms	remaining: 3.25s
# 3:	learn: 0.4773283	total: 37ms	remaining: 3.17s
# 4:	learn: 0.4329543	total: 45.3ms	remaining: 3.09s
# 5:	learn: 0.4033543	total: 53.4ms	remaining: 3.02s
# 6:	learn: 0.3822908	total: 61.8ms	remaining: 2.99s
# 7:	learn: 0.3576703	total: 69.6ms	remaining: 2.94s
# 8:	learn: 0.3392314	total: 77.8ms	remaining: 2.91s
# 9:	learn: 0.3245509	total: 86.1ms	remaining: 2.89s
# 10:	learn: 0.3060509	total: 94.5ms	remaining: 2.88s
# 11:	learn: 0.2938498	total: 103ms	remaining: 2.86s
# 12:	learn: 0.2796937	total: 111ms	remaining: 2.85s
# 13:	learn: 0.2723225	total: 119ms	remaining: 2.82s
# 14:	learn: 0.2647635	total: 127ms	remaining: 2.8s
# 15:	learn: 0.2553688	total: 135ms	remaining: 2.79s
# 16:	learn: 0.2486119	total: 144ms	remaining: 2.79s
# 17:	learn: 0.2400356	total: 152ms	remaining: 2.78s
# 18:	learn: 0.2333730	total: 162ms	remaining: 2.78s
# 19:	learn: 0.2264644	total: 170ms	remaining: 2.77s
# 20:	learn: 0.2218780	total: 179ms	remaining: 2.76s
# 21:	learn: 0.2168236	total: 186ms	remaining: 2.74s
# 22:	learn: 0.2129511	total: 195ms	remaining: 2.73s
# 23:	learn: 0.2062287	total: 203ms	remaining: 2.72s
# 24:	learn: 0.2014569	total: 211ms	remaining: 2.71s
# 25:	learn: 0.1975660	total: 219ms	remaining: 2.7s
# 26:	learn: 0.1915595	total: 227ms	remaining: 2.69s
# 27:	learn: 0.1875338	total: 236ms	remaining: 2.68s
# 28:	learn: 0.1849160	total: 245ms	remaining: 2.67s
# 29:	learn: 0.1830695	total: 252ms	remaining: 2.65s
# 30:	learn: 0.1803517	total: 261ms	remaining: 2.65s
# 31:	learn: 0.1775220	total: 268ms	remaining: 2.63s
# 32:	learn: 0.1760166	total: 276ms	remaining: 2.62s
# 33:	learn: 0.1721128	total: 284ms	remaining: 2.61s
# 34:	learn: 0.1697172	total: 293ms	remaining: 2.6s
# 35:	learn: 0.1676389	total: 301ms	remaining: 2.59s
# 36:	learn: 0.1665324	total: 310ms	remaining: 2.59s
# 37:	learn: 0.1627714	total: 319ms	remaining: 2.58s
# 38:	learn: 0.1591752	total: 327ms	remaining: 2.57s
# 39:	learn: 0.1560202	total: 335ms	remaining: 2.56s
# 40:	learn: 0.1538467	total: 343ms	remaining: 2.55s
# 41:	learn: 0.1525953	total: 351ms	remaining: 2.54s
# 42:	learn: 0.1513617	total: 360ms	remaining: 2.54s
# 43:	learn: 0.1505251	total: 369ms	remaining: 2.53s
# 44:	learn: 0.1480787	total: 377ms	remaining: 2.52s
# 45:	learn: 0.1463520	total: 386ms	remaining: 2.51s
# 46:	learn: 0.1460712	total: 390ms	remaining: 2.48s
# 47:	learn: 0.1451779	total: 399ms	remaining: 2.47s
# 48:	learn: 0.1441029	total: 408ms	remaining: 2.47s
# 49:	learn: 0.1419995	total: 416ms	remaining: 2.46s
# 50:	learn: 0.1404232	total: 424ms	remaining: 2.45s
# 51:	learn: 0.1387266	total: 432ms	remaining: 2.44s
# 52:	learn: 0.1379984	total: 440ms	remaining: 2.43s
# 53:	learn: 0.1373194	total: 448ms	remaining: 2.42s
# 54:	learn: 0.1354908	total: 461ms	remaining: 2.44s
# 55:	learn: 0.1346478	total: 469ms	remaining: 2.43s
# 56:	learn: 0.1340484	total: 478ms	remaining: 2.42s
# 57:	learn: 0.1334645	total: 486ms	remaining: 2.41s
# 58:	learn: 0.1327701	total: 494ms	remaining: 2.4s
# 59:	learn: 0.1322420	total: 502ms	remaining: 2.39s
# 60:	learn: 0.1309647	total: 510ms	remaining: 2.38s
# 61:	learn: 0.1295722	total: 518ms	remaining: 2.37s
# 62:	learn: 0.1287442	total: 527ms	remaining: 2.37s
# 63:	learn: 0.1277589	total: 535ms	remaining: 2.36s
# 64:	learn: 0.1272059	total: 543ms	remaining: 2.35s
# 65:	learn: 0.1265793	total: 551ms	remaining: 2.34s
# 66:	learn: 0.1261091	total: 560ms	remaining: 2.33s
# 67:	learn: 0.1252750	total: 569ms	remaining: 2.33s
# 68:	learn: 0.1247519	total: 577ms	remaining: 2.32s
# 69:	learn: 0.1244924	total: 586ms	remaining: 2.31s
# 70:	learn: 0.1237636	total: 594ms	remaining: 2.3s
# 71:	learn: 0.1231002	total: 602ms	remaining: 2.29s
# 72:	learn: 0.1225572	total: 610ms	remaining: 2.28s
# 73:	learn: 0.1219811	total: 619ms	remaining: 2.27s
# 74:	learn: 0.1208804	total: 627ms	remaining: 2.27s
# 75:	learn: 0.1206948	total: 635ms	remaining: 2.26s
# 76:	learn: 0.1205553	total: 643ms	remaining: 2.25s
# 77:	learn: 0.1203855	total: 651ms	remaining: 2.24s
# 78:	learn: 0.1198400	total: 659ms	remaining: 2.23s
# 79:	learn: 0.1192502	total: 667ms	remaining: 2.22s
# 80:	learn: 0.1190690	total: 675ms	remaining: 2.21s
# 81:	learn: 0.1187283	total: 684ms	remaining: 2.2s
# 82:	learn: 0.1182592	total: 692ms	remaining: 2.19s
# 83:	learn: 0.1177316	total: 700ms	remaining: 2.18s
# 84:	learn: 0.1176005	total: 708ms	remaining: 2.17s
# 85:	learn: 0.1173951	total: 717ms	remaining: 2.17s
# 86:	learn: 0.1170482	total: 726ms	remaining: 2.16s
# 87:	learn: 0.1166004	total: 734ms	remaining: 2.15s
# 88:	learn: 0.1164516	total: 743ms	remaining: 2.15s
# 89:	learn: 0.1160495	total: 752ms	remaining: 2.14s
# 90:	learn: 0.1159678	total: 762ms	remaining: 2.13s
# 91:	learn: 0.1158342	total: 771ms	remaining: 2.13s
# 92:	learn: 0.1156957	total: 779ms	remaining: 2.12s
# 93:	learn: 0.1154171	total: 788ms	remaining: 2.11s
# 94:	learn: 0.1151473	total: 796ms	remaining: 2.1s
# 95:	learn: 0.1150402	total: 804ms	remaining: 2.09s
# 96:	learn: 0.1148498	total: 813ms	remaining: 2.09s
# 97:	learn: 0.1147625	total: 823ms	remaining: 2.08s
# 98:	learn: 0.1142645	total: 831ms	remaining: 2.07s
# 99:	learn: 0.1140549	total: 839ms	remaining: 2.06s
# 100:	learn: 0.1140395	total: 844ms	remaining: 2.05s
# 101:	learn: 0.1139601	total: 853ms	remaining: 2.04s
# 102:	learn: 0.1139271	total: 862ms	remaining: 2.03s
# 103:	learn: 0.1138342	total: 870ms	remaining: 2.02s
# 104:	learn: 0.1137020	total: 879ms	remaining: 2.02s
# 105:	learn: 0.1135183	total: 887ms	remaining: 2.01s
# 106:	learn: 0.1134186	total: 901ms	remaining: 2.01s
# 107:	learn: 0.1132558	total: 910ms	remaining: 2s
# 108:	learn: 0.1130599	total: 918ms	remaining: 2s
# 109:	learn: 0.1127791	total: 926ms	remaining: 1.99s
# 110:	learn: 0.1127024	total: 936ms	remaining: 1.98s
# 111:	learn: 0.1126104	total: 944ms	remaining: 1.97s
# 112:	learn: 0.1123862	total: 958ms	remaining: 1.98s
# 113:	learn: 0.1122440	total: 968ms	remaining: 1.97s
# 114:	learn: 0.1120636	total: 977ms	remaining: 1.96s
# 115:	learn: 0.1118816	total: 985ms	remaining: 1.95s
# 116:	learn: 0.1118340	total: 993ms	remaining: 1.94s
# 117:	learn: 0.1117162	total: 1s	remaining: 1.93s
# 118:	learn: 0.1116638	total: 1.01s	remaining: 1.93s
# 119:	learn: 0.1116306	total: 1.02s	remaining: 1.92s
# 120:	learn: 0.1115026	total: 1.03s	remaining: 1.91s
# 121:	learn: 0.1114461	total: 1.03s	remaining: 1.9s
# 122:	learn: 0.1114036	total: 1.04s	remaining: 1.89s
# 123:	learn: 0.1113378	total: 1.05s	remaining: 1.88s
# 124:	learn: 0.1111963	total: 1.06s	remaining: 1.87s
# 125:	learn: 0.1111474	total: 1.07s	remaining: 1.86s
# 126:	learn: 0.1109502	total: 1.07s	remaining: 1.85s
# 127:	learn: 0.1108614	total: 1.08s	remaining: 1.85s
# 128:	learn: 0.1107991	total: 1.09s	remaining: 1.84s
# 129:	learn: 0.1107674	total: 1.1s	remaining: 1.83s
# 130:	learn: 0.1107365	total: 1.11s	remaining: 1.82s
# 131:	learn: 0.1106536	total: 1.12s	remaining: 1.81s
# 132:	learn: 0.1105401	total: 1.13s	remaining: 1.8s
# 133:	learn: 0.1104034	total: 1.14s	remaining: 1.79s
# 134:	learn: 0.1103171	total: 1.14s	remaining: 1.79s
# 135:	learn: 0.1102727	total: 1.15s	remaining: 1.78s
# 136:	learn: 0.1101876	total: 1.16s	remaining: 1.77s
# 137:	learn: 0.1100902	total: 1.17s	remaining: 1.76s
# 138:	learn: 0.1100539	total: 1.18s	remaining: 1.75s
# 139:	learn: 0.1099935	total: 1.19s	remaining: 1.75s
# 140:	learn: 0.1097691	total: 1.2s	remaining: 1.74s
# 141:	learn: 0.1097034	total: 1.2s	remaining: 1.73s
# 142:	learn: 0.1095899	total: 1.21s	remaining: 1.72s
# 143:	learn: 0.1094940	total: 1.22s	remaining: 1.71s
# 144:	learn: 0.1094655	total: 1.23s	remaining: 1.7s
# 145:	learn: 0.1093967	total: 1.24s	remaining: 1.69s
# 146:	learn: 0.1093016	total: 1.25s	remaining: 1.69s
# 147:	learn: 0.1092285	total: 1.25s	remaining: 1.68s
# 148:	learn: 0.1091841	total: 1.26s	remaining: 1.67s
# 149:	learn: 0.1090416	total: 1.27s	remaining: 1.66s
# 150:	learn: 0.1089800	total: 1.28s	remaining: 1.65s
# 151:	learn: 0.1089490	total: 1.29s	remaining: 1.64s
# 152:	learn: 0.1089151	total: 1.29s	remaining: 1.63s
# 153:	learn: 0.1088669	total: 1.3s	remaining: 1.62s
# 154:	learn: 0.1088077	total: 1.31s	remaining: 1.61s
# 155:	learn: 0.1087836	total: 1.32s	remaining: 1.61s
# 156:	learn: 0.1086252	total: 1.33s	remaining: 1.61s
# 157:	learn: 0.1085787	total: 1.34s	remaining: 1.6s
# 158:	learn: 0.1084869	total: 1.35s	remaining: 1.59s
# 159:	learn: 0.1084232	total: 1.36s	remaining: 1.58s
# 160:	learn: 0.1083719	total: 1.37s	remaining: 1.57s
# 161:	learn: 0.1083477	total: 1.38s	remaining: 1.56s
# 162:	learn: 0.1082816	total: 1.39s	remaining: 1.55s
# 163:	learn: 0.1082470	total: 1.39s	remaining: 1.55s
# 164:	learn: 0.1082145	total: 1.4s	remaining: 1.54s
# 165:	learn: 0.1081820	total: 1.41s	remaining: 1.53s
# 166:	learn: 0.1080701	total: 1.42s	remaining: 1.52s
# 167:	learn: 0.1080001	total: 1.43s	remaining: 1.51s
# 168:	learn: 0.1079483	total: 1.44s	remaining: 1.5s
# 169:	learn: 0.1079205	total: 1.44s	remaining: 1.49s
# 170:	learn: 0.1079028	total: 1.45s	remaining: 1.49s
# 171:	learn: 0.1078727	total: 1.46s	remaining: 1.48s
# 172:	learn: 0.1078277	total: 1.47s	remaining: 1.47s
# 173:	learn: 0.1077945	total: 1.48s	remaining: 1.46s
# 174:	learn: 0.1077606	total: 1.48s	remaining: 1.45s
# 175:	learn: 0.1077473	total: 1.49s	remaining: 1.44s
# 176:	learn: 0.1077347	total: 1.5s	remaining: 1.43s
# 177:	learn: 0.1076931	total: 1.51s	remaining: 1.42s
# 178:	learn: 0.1076490	total: 1.52s	remaining: 1.42s
# 179:	learn: 0.1075930	total: 1.52s	remaining: 1.41s
# 180:	learn: 0.1075614	total: 1.53s	remaining: 1.4s
# 181:	learn: 0.1075321	total: 1.54s	remaining: 1.39s
# 182:	learn: 0.1074662	total: 1.55s	remaining: 1.38s
# 183:	learn: 0.1073682	total: 1.56s	remaining: 1.37s
# 184:	learn: 0.1073470	total: 1.57s	remaining: 1.36s
# 185:	learn: 0.1073131	total: 1.57s	remaining: 1.35s
# 186:	learn: 0.1072521	total: 1.58s	remaining: 1.34s
# 187:	learn: 0.1071722	total: 1.59s	remaining: 1.34s
# 188:	learn: 0.1071349	total: 1.6s	remaining: 1.33s
# 189:	learn: 0.1070721	total: 1.61s	remaining: 1.32s
# 190:	learn: 0.1070413	total: 1.62s	remaining: 1.31s
# 191:	learn: 0.1070130	total: 1.63s	remaining: 1.3s
# 192:	learn: 0.1069877	total: 1.63s	remaining: 1.29s
# 193:	learn: 0.1069492	total: 1.64s	remaining: 1.29s
# 194:	learn: 0.1068994	total: 1.65s	remaining: 1.28s
# 195:	learn: 0.1068435	total: 1.66s	remaining: 1.27s
# 196:	learn: 0.1068230	total: 1.67s	remaining: 1.26s
# 197:	learn: 0.1068053	total: 1.68s	remaining: 1.25s
# 198:	learn: 0.1067301	total: 1.68s	remaining: 1.24s
# 199:	learn: 0.1067075	total: 1.69s	remaining: 1.24s
# 200:	learn: 0.1066933	total: 1.7s	remaining: 1.23s
# 201:	learn: 0.1066496	total: 1.71s	remaining: 1.22s
# 202:	learn: 0.1066306	total: 1.72s	remaining: 1.21s
# 203:	learn: 0.1066142	total: 1.73s	remaining: 1.2s
# 204:	learn: 0.1065804	total: 1.73s	remaining: 1.19s
# 205:	learn: 0.1065557	total: 1.74s	remaining: 1.18s
# 206:	learn: 0.1065292	total: 1.75s	remaining: 1.18s
# 207:	learn: 0.1065004	total: 1.76s	remaining: 1.17s
# 208:	learn: 0.1064203	total: 1.77s	remaining: 1.16s
# 209:	learn: 0.1064003	total: 1.78s	remaining: 1.15s
# 210:	learn: 0.1063605	total: 1.78s	remaining: 1.14s
# 211:	learn: 0.1063071	total: 1.79s	remaining: 1.13s
# 212:	learn: 0.1062762	total: 1.8s	remaining: 1.13s
# 213:	learn: 0.1062136	total: 1.81s	remaining: 1.12s
# 214:	learn: 0.1061823	total: 1.82s	remaining: 1.11s
# 215:	learn: 0.1061601	total: 1.83s	remaining: 1.1s
# 216:	learn: 0.1061361	total: 1.84s	remaining: 1.09s
# 217:	learn: 0.1061019	total: 1.84s	remaining: 1.08s
# 218:	learn: 0.1060759	total: 1.85s	remaining: 1.07s
# 219:	learn: 0.1060504	total: 1.86s	remaining: 1.07s
# 220:	learn: 0.1060198	total: 1.87s	remaining: 1.06s
# 221:	learn: 0.1059852	total: 1.88s	remaining: 1.05s
# 222:	learn: 0.1059609	total: 1.89s	remaining: 1.04s
# 223:	learn: 0.1059278	total: 1.9s	remaining: 1.03s
# 224:	learn: 0.1058950	total: 1.91s	remaining: 1.03s
# 225:	learn: 0.1058738	total: 1.92s	remaining: 1.02s
# 226:	learn: 0.1058273	total: 1.92s	remaining: 1.01s
# 227:	learn: 0.1058052	total: 1.93s	remaining: 1s
# 228:	learn: 0.1057538	total: 1.94s	remaining: 992ms
# 229:	learn: 0.1057245	total: 1.95s	remaining: 983ms
# 230:	learn: 0.1056869	total: 1.96s	remaining: 975ms
# 231:	learn: 0.1056457	total: 1.97s	remaining: 966ms
# 232:	learn: 0.1056202	total: 1.97s	remaining: 958ms
# 233:	learn: 0.1055843	total: 1.98s	remaining: 949ms
# 234:	learn: 0.1055605	total: 1.99s	remaining: 941ms
# 235:	learn: 0.1055336	total: 2s	remaining: 932ms
# 236:	learn: 0.1055120	total: 2.01s	remaining: 924ms
# 237:	learn: 0.1054807	total: 2.02s	remaining: 915ms
# 238:	learn: 0.1053596	total: 2.02s	remaining: 906ms
# 239:	learn: 0.1053386	total: 2.03s	remaining: 897ms
# 240:	learn: 0.1052929	total: 2.04s	remaining: 889ms
# 241:	learn: 0.1052640	total: 2.05s	remaining: 880ms
# 242:	learn: 0.1052178	total: 2.06s	remaining: 872ms
# 243:	learn: 0.1051831	total: 2.06s	remaining: 863ms
# 244:	learn: 0.1051631	total: 2.07s	remaining: 854ms
# 245:	learn: 0.1051201	total: 2.08s	remaining: 846ms
# 246:	learn: 0.1050848	total: 2.09s	remaining: 837ms
# 247:	learn: 0.1050643	total: 2.1s	remaining: 829ms
# 248:	learn: 0.1050379	total: 2.1s	remaining: 820ms
# 249:	learn: 0.1050022	total: 2.11s	remaining: 811ms
# 250:	learn: 0.1049717	total: 2.12s	remaining: 803ms
# 251:	learn: 0.1049468	total: 2.13s	remaining: 794ms
# 252:	learn: 0.1049268	total: 2.14s	remaining: 786ms
# 253:	learn: 0.1048711	total: 2.15s	remaining: 777ms
# 254:	learn: 0.1048549	total: 2.15s	remaining: 769ms
# 255:	learn: 0.1047572	total: 2.17s	remaining: 761ms
# 256:	learn: 0.1047435	total: 2.17s	remaining: 753ms
# 257:	learn: 0.1047121	total: 2.18s	remaining: 745ms
# 258:	learn: 0.1046738	total: 2.19s	remaining: 736ms
# 259:	learn: 0.1046539	total: 2.2s	remaining: 729ms
# 260:	learn: 0.1046164	total: 2.21s	remaining: 721ms
# 261:	learn: 0.1045768	total: 2.22s	remaining: 712ms
# 262:	learn: 0.1045384	total: 2.23s	remaining: 703ms
# 263:	learn: 0.1044949	total: 2.24s	remaining: 695ms
# 264:	learn: 0.1044668	total: 2.25s	remaining: 686ms
# 265:	learn: 0.1044500	total: 2.25s	remaining: 678ms
# 266:	learn: 0.1044295	total: 2.26s	remaining: 669ms
# 267:	learn: 0.1044024	total: 2.27s	remaining: 662ms
# 268:	learn: 0.1043747	total: 2.28s	remaining: 653ms
# 269:	learn: 0.1043546	total: 2.29s	remaining: 644ms
# 270:	learn: 0.1043102	total: 2.3s	remaining: 636ms
# 271:	learn: 0.1042589	total: 2.31s	remaining: 627ms
# 272:	learn: 0.1042347	total: 2.31s	remaining: 619ms
# 273:	learn: 0.1041800	total: 2.32s	remaining: 610ms
# 274:	learn: 0.1041542	total: 2.33s	remaining: 602ms
# 275:	learn: 0.1041354	total: 2.34s	remaining: 593ms
# 276:	learn: 0.1041139	total: 2.35s	remaining: 584ms
# 277:	learn: 0.1040390	total: 2.35s	remaining: 576ms
# 278:	learn: 0.1040222	total: 2.36s	remaining: 567ms
# 279:	learn: 0.1039990	total: 2.37s	remaining: 559ms
# 280:	learn: 0.1038884	total: 2.38s	remaining: 550ms
# 281:	learn: 0.1038789	total: 2.39s	remaining: 542ms
# 282:	learn: 0.1038338	total: 2.39s	remaining: 533ms
# 283:	learn: 0.1038065	total: 2.4s	remaining: 525ms
# 284:	learn: 0.1037358	total: 2.41s	remaining: 516ms
# 285:	learn: 0.1037036	total: 2.42s	remaining: 508ms
# 286:	learn: 0.1036752	total: 2.43s	remaining: 499ms
# 287:	learn: 0.1036408	total: 2.44s	remaining: 491ms
# 288:	learn: 0.1036083	total: 2.44s	remaining: 482ms
# 289:	learn: 0.1035942	total: 2.45s	remaining: 474ms
# 290:	learn: 0.1035701	total: 2.46s	remaining: 465ms
# 291:	learn: 0.1035487	total: 2.47s	remaining: 457ms
# 292:	learn: 0.1035254	total: 2.48s	remaining: 448ms
# 293:	learn: 0.1034935	total: 2.49s	remaining: 440ms
# 294:	learn: 0.1034667	total: 2.49s	remaining: 431ms
# 295:	learn: 0.1034487	total: 2.5s	remaining: 423ms
# 296:	learn: 0.1033951	total: 2.51s	remaining: 414ms
# 297:	learn: 0.1033642	total: 2.52s	remaining: 406ms
# 298:	learn: 0.1033423	total: 2.53s	remaining: 397ms
# 299:	learn: 0.1033034	total: 2.54s	remaining: 389ms
# 300:	learn: 0.1032804	total: 2.54s	remaining: 380ms
# 301:	learn: 0.1032523	total: 2.55s	remaining: 372ms
# 302:	learn: 0.1032301	total: 2.56s	remaining: 363ms
# 303:	learn: 0.1032022	total: 2.57s	remaining: 355ms
# 304:	learn: 0.1031557	total: 2.58s	remaining: 346ms
# 305:	learn: 0.1031287	total: 2.58s	remaining: 338ms
# 306:	learn: 0.1031067	total: 2.59s	remaining: 330ms
# 307:	learn: 0.1030855	total: 2.6s	remaining: 321ms
# 308:	learn: 0.1030473	total: 2.61s	remaining: 313ms
# 309:	learn: 0.1030043	total: 2.62s	remaining: 304ms
# 310:	learn: 0.1029742	total: 2.63s	remaining: 296ms
# 311:	learn: 0.1029482	total: 2.64s	remaining: 287ms
# 312:	learn: 0.1029254	total: 2.65s	remaining: 279ms
# 313:	learn: 0.1028906	total: 2.65s	remaining: 271ms
# 314:	learn: 0.1028649	total: 2.66s	remaining: 262ms
# 315:	learn: 0.1028343	total: 2.67s	remaining: 254ms
# 316:	learn: 0.1027947	total: 2.68s	remaining: 245ms
# 317:	learn: 0.1027603	total: 2.69s	remaining: 237ms
# 318:	learn: 0.1027265	total: 2.7s	remaining: 228ms
# 319:	learn: 0.1026884	total: 2.7s	remaining: 220ms
# 320:	learn: 0.1026738	total: 2.71s	remaining: 211ms
# 321:	learn: 0.1026347	total: 2.72s	remaining: 203ms
# 322:	learn: 0.1026154	total: 2.73s	remaining: 194ms
# 323:	learn: 0.1025851	total: 2.74s	remaining: 186ms
# 324:	learn: 0.1025496	total: 2.75s	remaining: 177ms
# 325:	learn: 0.1025179	total: 2.75s	remaining: 169ms
# 326:	learn: 0.1024796	total: 2.76s	remaining: 161ms
# 327:	learn: 0.1024493	total: 2.77s	remaining: 152ms
# 328:	learn: 0.1024346	total: 2.78s	remaining: 144ms
# 329:	learn: 0.1024016	total: 2.79s	remaining: 135ms
# 330:	learn: 0.1023713	total: 2.79s	remaining: 127ms
# 331:	learn: 0.1023544	total: 2.8s	remaining: 118ms
# 332:	learn: 0.1023359	total: 2.81s	remaining: 110ms
# 333:	learn: 0.1022753	total: 2.82s	remaining: 101ms
# 334:	learn: 0.1022510	total: 2.83s	remaining: 92.9ms
# 335:	learn: 0.1022285	total: 2.84s	remaining: 84.4ms
# 336:	learn: 0.1021856	total: 2.85s	remaining: 76ms
# 337:	learn: 0.1021594	total: 2.85s	remaining: 67.5ms
# 338:	learn: 0.1021443	total: 2.86s	remaining: 59.1ms
# 339:	learn: 0.1021058	total: 2.87s	remaining: 50.6ms
# 340:	learn: 0.1020517	total: 2.88s	remaining: 42.2ms
# 341:	learn: 0.1020225	total: 2.89s	remaining: 33.8ms
# 342:	learn: 0.1019943	total: 2.89s	remaining: 25.3ms
# 343:	learn: 0.1019625	total: 2.9s	remaining: 16.9ms
# 344:	learn: 0.1019357	total: 2.91s	remaining: 8.44ms
# 345:	learn: 0.1018920	total: 2.92s	remaining: 0us
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/work/Aimers/hari/mainwithaug.ipynb Cell 23 line 7
#       <a href='vscode-notebook-cell://proxy1.aitrain.ktcloud.com:10412/home/work/Aimers/hari/mainwithaug.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> final_clf.fit(X_tr_selec, y_tr, ) # use_best_model=True
#       <a href='vscode-notebook-cell://proxy1.aitrain.ktcloud.com:10412/home/work/Aimers/hari/mainwithaug.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> final_preds = final_clf.predict(X_te_selec)
# ----> <a href='vscode-notebook-cell://proxy1.aitrain.ktcloud.com:10412/home/work/Aimers/hari/mainwithaug.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> df_sub = pd.read_csv(os.path.join(config.data_path, "submission.csv"))
#       <a href='vscode-notebook-cell://proxy1.aitrain.ktcloud.com:10412/home/work/Aimers/hari/mainwithaug.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> df_sub["target"] = final_preds
#       <a href='vscode-notebook-cell://proxy1.aitrain.ktcloud.com:10412/home/work/Aimers/hari/mainwithaug.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> df_sub["target"] = df_sub["target"].map({0 : "Normal", 1 : "AbNormal"})
#
# File ~/prevenotics/miniconda3/envs/hrenv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/prevenotics/miniconda3/envs/hrenv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/prevenotics/miniconda3/envs/hrenv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/prevenotics/miniconda3/envs/hrenv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/prevenotics/miniconda3/envs/hrenv/lib/python3.12/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/submission.csv'

# %%
df_sub = pd.read_csv("/home/work/Aimers/data/submission.csv")
df_sub["target"] = final_preds
df_sub["target"] = df_sub["target"].map({0 : "Normal", 1 : "AbNormal"})

print('=============================')
print(df_sub["target"].value_counts())
# Out:
# =============================
# target
# Normal      17320
# AbNormal       41
# Name: count, dtype: int64

# %%
curr_date = datetime.now().strftime("%m-%d_%H-%M-%S")

# pickle.dump(final_clf, open(f"{config.model}_{curr_date}.pkl", "wb"))
# final_clf = pickle.load(open(".pkl", "rb"))
df_sub.to_csv(os.path.join(config.data_path, f"submission_{curr_date}_{exp_config}.csv"), index=False)
